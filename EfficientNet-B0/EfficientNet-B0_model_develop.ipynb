# %% [markdown]
# # Google Drive 마운트 절차

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 마운트된 드라이브의 파일 목록 확인
# !ls /content/drive/MyDrive
# Out:
# 'Colab Notebooks'   fruit_image_dataset
#  fruit_dataset	    fruits-fresh-and-rotten-for-classification.zip

# %% [markdown]
# # **1. 보유한 train, validation, test 이미지 데이터 증강(각 기법에 대해 10장씩만 생성 테스트)**
# ---
# **Augmentor** 설치 및 train 디렉토리의 fresh apple에 대해 시험적으로 10장씩 생성

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (9.4.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (4.66.5)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (1.26.4)
# Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %% [markdown]
# ## **1.1 train 디렉토리의 각 이미지 별 밝기 조절(10장 생성)**
# ---
# **Brightness Adjustment**
#
# 사용 예
#
# > p.random_brightness(probability=1.0, min_factor=0.4, max_factor=0.6)

# %% [markdown]
# ### **fresh apple**
# * **min_factor=0.4, max_factor=0.6**

# %%
import Augmentor

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/fresh apple", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/brightness test2")

# 밝기 조절을 추가
# min_factor: 최소 밝기 조정값 (1.0보다 작으면 더 어두워짐)
# max_factor: 최대 밝기 조정값 (1.0보다 크면 더 밝아짐)
p.random_brightness(probability=1.0, min_factor=0.4, max_factor=0.6)

# 증강된 이미지를 10장 생성하여 저장
p.sample(10)
# Out:
# Initialised with 75 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/train/brightness test2.
# Processing <PIL.Image.Image image mode=RGBA size=246x248 at 0x79FBBC327610>: 100%|██████████| 10/10 [00:00<00:00, 68.56 Samples/s]

# %% [markdown]
# ### **fresh orange**
# * **min_factor=0.9, max_factor=1.2**

# %%
import Augmentor

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/fresh orange", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/brightness test fresh orange")

# 밝기 조절을 추가
# min_factor: 최소 밝기 조정값 (1.0보다 작으면 더 어두워짐)
# max_factor: 최대 밝기 조정값 (1.0보다 크면 더 밝아짐)
p.random_brightness(probability=1.0, min_factor=0.9, max_factor=1.2)

# 증강된 이미지를 10장 생성하여 저장
p.sample(10)
# Out:
# Initialised with 75 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/train/brightness test fresh orange.
# Processing <PIL.Image.Image image mode=RGBA size=376x314 at 0x7D1190DF2050>: 100%|██████████| 10/10 [00:00<00:00, 62.99 Samples/s]

# %% [markdown]
# ### **rotten apple**
# * **min_factor=0.4, max_factor=0.6**

# %%
import Augmentor

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/rotten apple", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/brightness test rotten apple")

# 밝기 조절을 추가
# min_factor: 최소 밝기 조정값 (1.0보다 작으면 더 어두워짐)
# max_factor: 최대 밝기 조정값 (1.0보다 크면 더 밝아짐)
p.random_brightness(probability=1.0, min_factor=0.4, max_factor=0.6)

# 증강된 이미지를 10장 생성하여 저장
p.sample(10)
# Out:
# Initialised with 75 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/train/brightness test rotten apple.
# Processing <PIL.Image.Image image mode=RGBA size=334x408 at 0x79B60823FEE0>: 100%|██████████| 10/10 [00:00<00:00, 60.69 Samples/s]

# %% [markdown]
# ### **rotten orange**
# * **min_factor=0.9, max_factor=1.2**

# %%
import Augmentor

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/rotten orange", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/brightness test rotten orange")

# 밝기 조절을 추가
# min_factor: 최소 밝기 조정값 (1.0보다 작으면 더 어두워짐)
# max_factor: 최대 밝기 조정값 (1.0보다 크면 더 밝아짐)
p.random_brightness(probability=1.0, min_factor=0.9, max_factor=1.2)

# 증강된 이미지를 10장 생성하여 저장
p.sample(10)
# Out:
# Initialised with 75 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/train/brightness test rotten orange.
# Processing <PIL.Image.Image image mode=RGBA size=458x424 at 0x7D11900424A0>: 100%|██████████| 10/10 [00:00<00:00, 59.04 Samples/s]

# %% [markdown]
# ## **1.2 train 디렉토리의 각 이미지 별 대비 조절(10장 생성)**
# ---
# **Contrast Adjustment**(이미지의 선명도 조절)
#
# 사용 예
#
# > p.random_contrast(probability=1.0, min_factor=0.8, max_factor=1.5)

# %% [markdown]
# ### **fresh apple**
# * **min_factor=0.8, max_factor=1.5**

# %%
import Augmentor

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/fresh apple", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/contrast test")

# 대비 조정을 추가
# min_factor: 최소 대비 조정값 (1.0보다 작으면 대비가 감소됨 ~> 흐릿한 이미지)
# max_factor: 최대 대비 조정값 (1.0보다 크면 대비가 증가됨 ~> 선명한 이미지)
p.random_contrast(probability=1.0, min_factor=0.8, max_factor=1.5)

# 증강된 이미지를 10장 생성하여 저장
p.sample(10)
# Out:
# Initialised with 75 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/train/contrast test.
# Processing <PIL.Image.Image image mode=RGB size=382x350 at 0x79FBBC378BB0>: 100%|██████████| 10/10 [00:00<00:00, 53.14 Samples/s]

# %% [markdown]
# ### **fresh orange**
# * **min_factor=0.8, max_factor=1.5**

# %%
import Augmentor

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/fresh orange", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/contrast test fresh orange")

# 대비 조정을 추가
# min_factor: 최소 대비 조정값 (1.0보다 작으면 대비가 감소됨 ~> 흐릿한 이미지)
# max_factor: 최대 대비 조정값 (1.0보다 크면 대비가 증가됨 ~> 선명한 이미지)
p.random_contrast(probability=1.0, min_factor=0.8, max_factor=1.5)

# 증강된 이미지를 10장 생성하여 저장
p.sample(10)
# Out:
# Initialised with 75 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/train/contrast test fresh orange.
# Processing <PIL.Image.Image image mode=RGBA size=406x374 at 0x7D1190043700>: 100%|██████████| 10/10 [00:00<00:00, 20.26 Samples/s]

# %% [markdown]
# ### **rotten apple**
# * **min_factor=0.8, max_factor=1.5**

# %%
import Augmentor

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/rotten apple", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/contrast test rotten apple")

# 대비 조정을 추가
# min_factor: 최소 대비 조정값 (1.0보다 작으면 대비가 감소됨 ~> 흐릿한 이미지)
# max_factor: 최대 대비 조정값 (1.0보다 크면 대비가 증가됨 ~> 선명한 이미지)
p.random_contrast(probability=1.0, min_factor=0.8, max_factor=1.5)

# 증강된 이미지를 10장 생성하여 저장
p.sample(10)
# Out:
# Initialised with 75 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/train/contrast test rotten apple.
# Processing <PIL.Image.Image image mode=RGBA size=278x298 at 0x79B608298BE0>: 100%|██████████| 10/10 [00:00<00:00, 60.42 Samples/s]

# %% [markdown]
# ### **rotten orange**
# * **min_factor=0.8, max_factor=1.5**

# %%
import Augmentor

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/rotten orange", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/contrast test rotten orange")

# 대비 조정을 추가
# min_factor: 최소 대비 조정값 (1.0보다 작으면 대비가 감소됨 ~> 흐릿한 이미지)
# max_factor: 최대 대비 조정값 (1.0보다 크면 대비가 증가됨 ~> 선명한 이미지)
p.random_contrast(probability=1.0, min_factor=0.8, max_factor=1.5)

# 증강된 이미지를 10장 생성하여 저장
p.sample(10)
# Out:
# Initialised with 75 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/train/contrast test rotten orange.
# Processing <PIL.Image.Image image mode=RGBA size=430x408 at 0x7D1190015DB0>: 100%|██████████| 10/10 [00:00<00:00, 25.47 Samples/s]

# %% [markdown]
# ## **1.3 train 디렉토리의 각 이미지 별 색상 조절(10장 생성)**
# ---
# **Color Adjustment**(이미지를 임의로 색상 조정. 이미지의 색상을 변경하여 다른 조명 조건을 모사.)
#
# 사용 예
#
# > p.random_color(probability=1.0, min_factor=0.7, max_factor=0.8)

# %% [markdown]
# ### **fresh apple**
# * **min_factor=0.7, max_factor=0.8**

# %%
import Augmentor

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/fresh apple", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/color test")

# 만약 디렉토리가 없는 경우 생성
if not os.path.exists("/content/drive/MyDrive/fruit_image_dataset/dataset/train/color test"):
    os.makedirs("/content/drive/MyDrive/fruit_image_dataset/dataset/train/color test")

# RandomColor 변형을 추가
# min_factor: 색상 조정의 최소값 (0.5는 색상을 절반으로 줄임)
# max_factor: 색상 조정의 최대값 (1.5는 색상을 1.5배 증가시킴)
p.random_color(probability=1.0, min_factor=0.7, max_factor=0.8)

# 증강된 이미지를 75장 생성하여 저장
p.sample(75)
# Out:
# Initialised with 75 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/train/color test.
# Processing <PIL.Image.Image image mode=RGBA size=462x466 at 0x79F8009E79D0>: 100%|██████████| 75/75 [00:00<00:00, 78.29 Samples/s]

# %% [markdown]
# ### **fresh orange**
# * **min_factor=0.8, max_factor=1.2**

# %%
import Augmentor

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/fresh orange", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/color test fresh orange")

# 만약 디렉토리가 없는 경우 생성
#if not os.path.exists("/content/drive/MyDrive/fruit_image_dataset/dataset/train/color test fresh orange"):
    #os.makedirs("/content/drive/MyDrive/fruit_image_dataset/dataset/train/color test fresh orange")

# RandomColor 변형을 추가
# min_factor: 색상 조정의 최소값 (0.5는 색상을 절반으로 줄임)
# max_factor: 색상 조정의 최대값 (1.5는 색상을 1.5배 증가시킴)
p.random_color(probability=1.0, min_factor=0.8, max_factor=1.2)

# 증강된 이미지를 75장 생성하여 저장
p.sample(75)
# Out:
# Initialised with 75 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/train/color test fresh orange.
# Processing <PIL.Image.Image image mode=RGBA size=374x354 at 0x7D117C5E39A0>: 100%|██████████| 75/75 [00:00<00:00, 95.74 Samples/s]

# %% [markdown]
# ### **rotten apple**
# * **min_factor=0.7, max_factor=0.8**

# %%
# rotten apple

import Augmentor

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/rotten apple", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/color test rotten apple")

# 만약 디렉토리가 없는 경우 생성
if not os.path.exists("/content/drive/MyDrive/fruit_image_dataset/dataset/train/color test rotten apple"):
    os.makedirs("/content/drive/MyDrive/fruit_image_dataset/dataset/train/color test rotten apple")

# RandomColor 변형을 추가
# min_factor: 색상 조정의 최소값 (0.5는 색상을 절반으로 줄임)
# max_factor: 색상 조정의 최대값 (1.5는 색상을 1.5배 증가시킴)
p.random_color(probability=1.0, min_factor=0.7, max_factor=0.8)

# 증강된 이미지를 10장 생성하여 저장
p.sample(10)
# Out:
# Initialised with 75 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/train/color test rotten apple.
# Processing <PIL.Image.Image image mode=RGBA size=452x382 at 0x79F8009E7730>: 100%|██████████| 10/10 [00:00<00:00, 61.58 Samples/s]

# %% [markdown]
# ### **rotten orange**
# * **min_factor=0.8, max_factor=1.2**

# %%
import Augmentor
import os

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/rotten orange", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/color test rotten orange")

# 만약 디렉토리가 없는 경우 생성
if not os.path.exists("/content/drive/MyDrive/fruit_image_dataset/dataset/train/color test rotten orange"):
    os.makedirs("/content/drive/MyDrive/fruit_image_dataset/dataset/train/color test rotten orange")

# RandomColor 변형을 추가
# min_factor: 색상 조정의 최소값 (0.5는 색상을 절반으로 줄임)
# max_factor: 색상 조정의 최대값 (1.5는 색상을 1.5배 증가시킴)
p.random_color(probability=1.0, min_factor=0.8, max_factor=1.2)

# 증강된 이미지를 75장 생성하여 저장
p.sample(75)
# Out:
# Initialised with 1000 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/train/color test rotten orange.
# Processing <PIL.Image.Image image mode=RGBA size=458x392 at 0x7C337416C8E0>: 100%|██████████| 75/75 [00:00<00:00, 77.46 Samples/s]

# %% [markdown]
# ## **1.4 train 디렉토리의 이미지 별 채도 조절(10장 생성)(Augmentor가 지원하지 않음)**
# ---
# **Saturation Adjustment**(이미지의 색상 강도 조절. 다양한 조명 환경을 시뮬레이션할 수 있음)

# %% [markdown]
# ### **fresh apple**
# * **0.8**

# %%
import cv2
import numpy as np
import os

# 이미지 파일이 있는 디렉터리를 지정
source_directory = "/content/drive/MyDrive/fruit_image_dataset/dataset/train/fresh apple"
output_directory = "/content/drive/MyDrive/fruit_image_dataset/dataset/train/saturation test"

# 디렉터리가 없는 경우 생성
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# 이미지 파일 처리 (파일명 알파벳순 정렬)
file_list = sorted(os.listdir(source_directory))
processed_count = 0  # 처리한 이미지 수를 추적하기 위한 변수

for filename in file_list:
    if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
        image_path = os.path.join(source_directory, filename)
        image = cv2.imread(image_path)

        if image is None:
            print(f"Warning: Unable to read image {filename}. Skipping.")
            continue

        # BGR 이미지를 HSV로 변환
        hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

        # 채도(Saturation) 조정 - 하나의 값(0.8)으로 조정
        hsv_image[:, :, 1] = hsv_image[:, :, 1] * 0.8  # Saturation 값 0.8로 설정

        # HSV 이미지를 다시 BGR로 변환
        adjusted_image = cv2.cvtColor(hsv_image, cv2.COLOR_HSV2BGR)
        output_path = os.path.join(output_directory, f"{os.path.splitext(filename)[0]}_saturation_adjusted.png")
        cv2.imwrite(output_path, adjusted_image)

        processed_count += 1
        if processed_count >= 10:  # 10개의 이미지에 대해서만 처리
            break

print("Saturation adjustment completed for 10 images.")
# Out:
# Saturation adjustment completed for 10 images.

# %% [markdown]
# ### **rotten apple**
# * **0.8**

# %%
import cv2
import numpy as np
import os

# 이미지 파일이 있는 디렉터리를 지정
source_directory = "/content/drive/MyDrive/fruit_image_dataset/dataset/train/rotten apple"
output_directory = "/content/drive/MyDrive/fruit_image_dataset/dataset/train/saturation test rotten apple"

# 디렉터리가 없는 경우 생성
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# 이미지 파일 처리 (파일명 알파벳순 정렬)
file_list = sorted(os.listdir(source_directory))
processed_count = 0  # 처리한 이미지 수를 추적하기 위한 변수

for filename in file_list:
    if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
        image_path = os.path.join(source_directory, filename)
        image = cv2.imread(image_path)

        if image is None:
            print(f"Warning: Unable to read image {filename}. Skipping.")
            continue

        # BGR 이미지를 HSV로 변환
        hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

        # 채도(Saturation) 조정 - 하나의 값(0.8)으로 조정
        hsv_image[:, :, 1] = hsv_image[:, :, 1] * 0.8  # Saturation 값 0.8로 설정

        # HSV 이미지를 다시 BGR로 변환
        adjusted_image = cv2.cvtColor(hsv_image, cv2.COLOR_HSV2BGR)
        output_path = os.path.join(output_directory, f"{os.path.splitext(filename)[0]}_saturation_adjusted.png")
        cv2.imwrite(output_path, adjusted_image)

        processed_count += 1
        if processed_count >= 10:  # 10개의 이미지에 대해서만 처리
            break

print("Saturation adjustment completed for 10 images.")
# Out:
# Saturation adjustment completed for 10 images.

# %% [markdown]
# ### **fresh orange**
# * **1.2**

# %%
import cv2
import numpy as np
import os

# 이미지 파일이 있는 디렉터리를 지정
source_directory = "/content/drive/MyDrive/fruit_image_dataset/dataset/train/fresh orange"
output_directory = "/content/drive/MyDrive/fruit_image_dataset/dataset/train/saturation test fresh orange"

# 디렉터리가 없는 경우 생성
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# 이미지 파일 처리 (파일명 알파벳순 정렬)
file_list = sorted(os.listdir(source_directory))
processed_count = 0  # 처리한 이미지 수를 추적하기 위한 변수

for filename in file_list:
    # 파일 확장자를 소문자로 비교하여 확인
    if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
        image_path = os.path.join(source_directory, filename)

        # 이미지 파일 읽기
        image = cv2.imread(image_path)

        if image is None:
            print(f"Warning: Unable to read image {filename}. Skipping.")
            continue

        # BGR 이미지를 HSV로 변환
        hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

        # 채도(Saturation) 조정 - 하나의 값(1.2)으로 조정
        hsv_image[:, :, 1] = hsv_image[:, :, 1] * 1.2  # Saturation 값 1.2로 설정

        # HSV 이미지를 다시 BGR로 변환
        adjusted_image = cv2.cvtColor(hsv_image, cv2.COLOR_HSV2BGR)

        # 결과 저장
        output_path = os.path.join(output_directory, f"{os.path.splitext(filename)[0]}_saturation_adjusted.png")
        cv2.imwrite(output_path, adjusted_image)

        processed_count += 1
        if processed_count >= 75:  # 75개의 이미지에 대해서만 처리
            break

print("Saturation adjustment completed for 75 images.")
# Out:
# Saturation adjustment completed for 75 images.

# %% [markdown]
# ### **rotten orange**
# * **0.9**

# %%
import cv2
import numpy as np
import os

# 이미지 파일이 있는 디렉터리를 지정
source_directory = "/content/drive/MyDrive/fruit_image_dataset/dataset/train/rotten orange"
output_directory = "/content/drive/MyDrive/fruit_image_dataset/dataset/train/saturation test rotten orange"

# 디렉터리가 없는 경우 생성
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# 이미지 파일 처리 (파일명 알파벳순 정렬)
file_list = sorted(os.listdir(source_directory))
processed_count = 0  # 처리한 이미지 수를 추적하기 위한 변수

for filename in file_list:
    if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
        image_path = os.path.join(source_directory, filename)
        image = cv2.imread(image_path)

        if image is None:
            print(f"Warning: Unable to read image {filename}. Skipping.")
            continue

        # BGR 이미지를 HSV로 변환
        hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

        # 채도(Saturation) 조정 - 하나의 값(0.9)으로 조정
        hsv_image[:, :, 1] = hsv_image[:, :, 1] * 0.9  # Saturation 값 0.9로 설정

        # HSV 이미지를 다시 BGR로 변환
        adjusted_image = cv2.cvtColor(hsv_image, cv2.COLOR_HSV2BGR)
        output_path = os.path.join(output_directory, f"{os.path.splitext(filename)[0]}_saturation_adjusted.png")
        cv2.imwrite(output_path, adjusted_image)

        processed_count += 1
        if processed_count >= 75:  # 75개의 이미지에 대해서만 처리
            break

print("Saturation adjustment completed for 75 images.")
# Out:
# Saturation adjustment completed for 75 images.

# %% [markdown]
# ## **1.5 train, validation 데이터들에 대해 사용할 색상 변형 기법 4가지 정리**
# * 밝기 조정 (Brightness Adjustment)
# * 선명도 조절 (Contrast Adjustment)
# * 색상 조정 (Color Adjustment) : 이미지를 임의로 색상 조정. 이미지의 색상을 변경하여 다른 조명 조건을 모사.
# * 채도 변경 (Saturation Adjustment) : 이미지의 색상 강도를 조절하는 기법으로, 색상을 더 생생하게 만들거나 덜 강하게 만듦. 이를 통해 자연광, 인공 조명 등 다양한 조명 환경을 시뮬레이션할 수 있음.

# %% [markdown]
# ## **1.6 test 데이터들에 대해 사용할 증강 기법 정리**
# * 좌우 대칭

# %% [markdown]
# # **2. 보유한 train, validation, test 이미지 데이터에 대해 증강 진행**
# ---
# 총 4개의 항목(**fresh apple**, **rotten apple**, **fresh banana**, **rotten banana**)
#
# * **Train 데이터** : (기존)75장 ➡ (증강)**1000장**
# * **Validation 데이터** : (기존)25장 ➡ (증강)**200장**
# * **Test 데이터** : (기존)30장 ➡ (증강)**90장**
#
# 합계
# * Train 데이터 : 1000x4 = **4000장**
# * Validation 데이터 : 200x4 = **800장**
# * Test 데이터 : 90x4 = **360장**
#
# **Test 데이터에 대해선 좌우 대칭만 적용**

# %% [markdown]
# ## **2.1 train, validation 이미지들**

# %% [markdown]
# ### **2.1.1 train**

# %% [markdown]
# #### **fresh apple**

# %%
# 밝기 조절
# min_factor=0.4, max_factor=0.6

import Augmentor
import os

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/fresh apple", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/Brightness Adjustment fresh apple")

# 만약 디렉터리가 없는 경우 생성
if not os.path.exists("/content/drive/MyDrive/fruit_image_dataset/dataset/train/Brightness Adjustment fresh apple"):
    os.makedirs("/content/drive/MyDrive/fruit_image_dataset/dataset/train/Brightness Adjustment fresh apple")

# 밝기 조절을 추가
# min_factor: 최소 밝기 조정값 (1.0보다 작으면 더 어두워짐)
# max_factor: 최대 밝기 조정값 (1.0보다 크면 더 밝아짐)
p.random_brightness(probability=1.0, min_factor=0.4, max_factor=0.6)

# 증강된 이미지를 370장 생성하여 저장
p.sample(370)
# Out:
# Initialised with 75 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/train/Brightness Adjustment fresh apple.
# Processing <PIL.Image.Image image mode=RGB size=184x172 at 0x7C8138388040>: 100%|██████████| 370/370 [00:03<00:00, 96.69 Samples/s]

# %%
# 대비 조절
# min_factor=0.8, max_factor=1.5

import Augmentor
import os

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/fresh apple", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/Contrast Adjustment fresh apple")

# 만약 디렉터리가 없는 경우 생성
if not os.path.exists("/content/drive/MyDrive/fruit_image_dataset/dataset/train/Contrast Adjustment fresh apple"):
    os.makedirs("/content/drive/MyDrive/fruit_image_dataset/dataset/train/Contrast Adjustment fresh apple")

# 대비 조정을 추가
# min_factor: 최소 대비 조정값 (1.0보다 작으면 대비가 감소됨 ~> 흐릿한 이미지)
# max_factor: 최대 대비 조정값 (1.0보다 크면 대비가 증가됨 ~> 선명한 이미지)
p.random_contrast(probability=1.0, min_factor=0.8, max_factor=1.5)

# 증강된 이미지를 185장 생성하여 저장
p.sample(185)
# Out:
# Initialised with 75 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/train/Contrast Adjustment fresh apple.
# Processing <PIL.Image.Image image mode=RGBA size=472x462 at 0x7C81383567A0>: 100%|██████████| 185/185 [00:01<00:00, 94.51 Samples/s]

# %%
# 색상 조절
# min_factor=0.7, max_factor=0.8

import Augmentor
import os

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/fresh apple", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/Color Adjustment fresh apple")

# 만약 디렉터리가 없는 경우 생성
if not os.path.exists("/content/drive/MyDrive/fruit_image_dataset/dataset/train/Color Adjustment fresh apple"):
    os.makedirs("/content/drive/MyDrive/fruit_image_dataset/dataset/train/Color Adjustment fresh apple")

# 대비 조정을 추가
# min_factor: 최소 대비 조정값 (1.0보다 작으면 대비가 감소됨 ~> 흐릿한 이미지)
# max_factor: 최대 대비 조정값 (1.0보다 크면 대비가 증가됨 ~> 선명한 이미지)
p.random_contrast(probability=1.0, min_factor=0.7, max_factor=0.8)

# 증강된 이미지를 185장 생성하여 저장
p.sample(185)
# Out:
# Initialised with 75 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/train/Color Adjustment fresh apple.
# Processing <PIL.Image.Image image mode=RGBA size=470x452 at 0x7C813833EAD0>: 100%|██████████| 185/185 [00:02<00:00, 90.87 Samples/s]

# %%
# 채도 조절
# Saturation 값 0.8

import cv2
import numpy as np
import os

# 이미지 파일이 있는 디렉터리를 지정
source_directory = "/content/drive/MyDrive/fruit_image_dataset/dataset/train/fresh apple"
output_directory = "/content/drive/MyDrive/fruit_image_dataset/dataset/train/Saturation Adjustment fresh apple"

# 디렉터리가 없는 경우 생성
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# 이미지 파일 처리 (파일명 알파벳순 정렬)
file_list = sorted(os.listdir(source_directory))
processed_count = 0  # 처리한 이미지 수를 추적하기 위한 변수

# 필요한 이미지 수가 채워질 때까지 루프 실행
while processed_count < 185:
    for filename in file_list:
        if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
            image_path = os.path.join(source_directory, filename)
            image = cv2.imread(image_path)

            if image is None:
                print(f"Warning: Unable to read image {filename}. Skipping.")
                continue

            # BGR 이미지를 HSV로 변환
            hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

            # 채도(Saturation) 조정 - 하나의 값(0.8)으로 조정
            hsv_image[:, :, 1] = hsv_image[:, :, 1] * 0.8  # Saturation 값 0.8로 설정

            # HSV 이미지를 다시 BGR로 변환
            adjusted_image = cv2.cvtColor(hsv_image, cv2.COLOR_HSV2BGR)
            output_path = os.path.join(output_directory, f"{os.path.splitext(filename)[0]}_saturation_adjusted_{processed_count}.png")
            cv2.imwrite(output_path, adjusted_image)

            processed_count += 1
            if processed_count >= 185:  # 185개의 이미지에 대해서만 처리
                break

print("Saturation adjustment completed for 185 images.")
# Out:
# Saturation adjustment completed for 185 images.

# %% [markdown]
# #### **fresh orange**

# %%
# 밝기 조절
# min_factor=0.9, max_factor=1.2

import Augmentor
import os

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/fresh orange", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/Brightness Adjustment fresh orange")

# 밝기 조절을 추가
# min_factor: 최소 밝기 조정값 (1.0보다 작으면 더 어두워짐)
# max_factor: 최대 밝기 조정값 (1.0보다 크면 더 밝아짐)
p.random_brightness(probability=1.0, min_factor=0.9, max_factor=1.2)

# 증강된 이미지를 185장 생성하여 저장
p.sample(185)
# Out:
# Initialised with 75 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/train/Brightness Adjustment fresh orange.
# Processing <PIL.Image.Image image mode=RGBA size=376x314 at 0x7F98683AD3F0>: 100%|██████████| 185/185 [00:01<00:00, 98.93 Samples/s]

# %%
# 대비 조절
# min_factor=0.8, max_factor=1.5

import Augmentor
import os

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/fresh orange", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/Contrast Adjustment fresh orange")

# 대비 조정을 추가
# min_factor: 최소 대비 조정값 (1.0보다 작으면 대비가 감소됨 ~> 흐릿한 이미지)
# max_factor: 최대 대비 조정값 (1.0보다 크면 대비가 증가됨 ~> 선명한 이미지)
p.random_contrast(probability=1.0, min_factor=0.8, max_factor=1.5)

# 증강된 이미지를 185장 생성하여 저장
p.sample(185)
# Out:
# Initialised with 75 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/train/Contrast Adjustment fresh orange.
# Processing <PIL.Image.Image image mode=RGBA size=390x350 at 0x7F986835E950>: 100%|██████████| 185/185 [00:01<00:00, 102.70 Samples/s]

# %%
# 색상 조절
# min_factor=0.8, max_factor=1.2

import Augmentor
import os

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/fresh orange", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/Color Adjustment fresh orange")

# 대비 조정을 추가
# min_factor: 최소 대비 조정값 (1.0보다 작으면 대비가 감소됨 ~> 흐릿한 이미지)
# max_factor: 최대 대비 조정값 (1.0보다 크면 대비가 증가됨 ~> 선명한 이미지)
p.random_contrast(probability=1.0, min_factor=0.8, max_factor=1.2)

# 증강된 이미지를 185장 생성하여 저장
p.sample(370)
# Out:
# Initialised with 75 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/train/Color Adjustment fresh orange.
# Processing <PIL.Image.Image image mode=RGB size=318x352 at 0x7F98682EB130>: 100%|██████████| 370/370 [00:03<00:00, 97.14 Samples/s]

# %%
# 채도 조절
# 1.2

import cv2
import numpy as np
import os

# 이미지 파일이 있는 디렉터리를 지정
source_directory = "/content/drive/MyDrive/fruit_image_dataset/dataset/train/fresh orange"
output_directory = "/content/drive/MyDrive/fruit_image_dataset/dataset/train/Saturation Adjustment fresh orange"

# 디렉터리가 없는 경우 생성
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# 이미지 파일 처리 (파일명 알파벳순 정렬)
file_list = sorted(os.listdir(source_directory))
processed_count = 0  # 처리한 이미지 수를 추적하기 위한 변수

# 필요한 이미지 수가 채워질 때까지 루프 실행
while processed_count < 185:
    for filename in file_list:
        if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
            image_path = os.path.join(source_directory, filename)
            image = cv2.imread(image_path)

            if image is None:
                print(f"Warning: Unable to read image {filename}. Skipping.")
                continue

            # BGR 이미지를 HSV로 변환
            hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

            # 채도(Saturation) 조정 - 하나의 값(1.2)으로 조정
            hsv_image[:, :, 1] = hsv_image[:, :, 1] * 1.2  # Saturation 값 1.2로 설정

            # HSV 이미지를 다시 BGR로 변환
            adjusted_image = cv2.cvtColor(hsv_image, cv2.COLOR_HSV2BGR)
            output_path = os.path.join(output_directory, f"{os.path.splitext(filename)[0]}_saturation_adjusted_{processed_count}.png")
            cv2.imwrite(output_path, adjusted_image)

            processed_count += 1
            if processed_count >= 185:  # 185개의 이미지에 대해서만 처리
                break

print("Saturation adjustment completed for 185 images.")
# Out:
# Saturation adjustment completed for 185 images.

# %% [markdown]
# #### **rotten apple**

# %%
# 밝기 조절
# min_factor=0.4, max_factor=0.6

import Augmentor
import os

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/rotten apple", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/Brightness Adjustment rotten apple")

# 만약 디렉터리가 없는 경우 생성
if not os.path.exists("/content/drive/MyDrive/fruit_image_dataset/dataset/train/Brightness Adjustment rotten apple"):
    os.makedirs("/content/drive/MyDrive/fruit_image_dataset/dataset/train/Brightness Adjustment rotten apple")

# 밝기 조절을 추가
# min_factor: 최소 밝기 조정값 (1.0보다 작으면 더 어두워짐)
# max_factor: 최대 밝기 조정값 (1.0보다 크면 더 밝아짐)
p.random_brightness(probability=1.0, min_factor=0.4, max_factor=0.6)

# 증강된 이미지를 370장 생성하여 저장
p.sample(370)
# Out:
# Initialised with 75 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/train/Brightness Adjustment rotten apple.
# Processing <PIL.Image.Image image mode=RGBA size=368x396 at 0x7A493566BDF0>: 100%|██████████| 370/370 [00:04<00:00, 86.77 Samples/s]

# %%
# 대비 조절
# min_factor=0.8, max_factor=1.5

import Augmentor
import os

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/rotten apple", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/Contrast Adjustment rotten apple")

# 만약 디렉터리가 없는 경우 생성
if not os.path.exists("/content/drive/MyDrive/fruit_image_dataset/dataset/train/Contrast Adjustment rotten apple"):
    os.makedirs("/content/drive/MyDrive/fruit_image_dataset/dataset/train/Contrast Adjustment rotten apple")

# 대비 조정을 추가
# min_factor: 최소 대비 조정값 (1.0보다 작으면 대비가 감소됨 ~> 흐릿한 이미지)
# max_factor: 최대 대비 조정값 (1.0보다 크면 대비가 증가됨 ~> 선명한 이미지)
p.random_contrast(probability=1.0, min_factor=0.8, max_factor=1.5)

# 증강된 이미지를 185장 생성하여 저장
p.sample(185)
# Out:
# Initialised with 75 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/train/Contrast Adjustment rotten apple.
# Processing <PIL.Image.Image image mode=RGBA size=350x408 at 0x7A492176A1D0>: 100%|██████████| 185/185 [00:02<00:00, 86.00 Samples/s]

# %%
# 색상 조절
# min_factor=0.7, max_factor=0.8

import Augmentor
import os

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/rotten apple", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/Color Adjustment rotten apple")

# 만약 디렉터리가 없는 경우 생성
if not os.path.exists("/content/drive/MyDrive/fruit_image_dataset/dataset/train/Color Adjustment rotten apple"):
    os.makedirs("/content/drive/MyDrive/fruit_image_dataset/dataset/train/Color Adjustment rotten apple")

# 대비 조정을 추가
# min_factor: 최소 대비 조정값 (1.0보다 작으면 대비가 감소됨 ~> 흐릿한 이미지)
# max_factor: 최대 대비 조정값 (1.0보다 크면 대비가 증가됨 ~> 선명한 이미지)
p.random_contrast(probability=1.0, min_factor=0.7, max_factor=0.8)

# 증강된 이미지를 185장 생성하여 저장
p.sample(185)
# Out:
# Initialised with 75 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/train/Color Adjustment rotten apple.
# Processing <PIL.Image.Image image mode=RGBA size=340x412 at 0x7A492172F0D0>: 100%|██████████| 185/185 [00:02<00:00, 83.23 Samples/s]

# %%
# 채도 조절
# 0.8

import cv2
import numpy as np
import os

# 이미지 파일이 있는 디렉터리를 지정
source_directory = "/content/drive/MyDrive/fruit_image_dataset/dataset/train/rotten apple"
output_directory = "/content/drive/MyDrive/fruit_image_dataset/dataset/train/Saturation Adjustment rotten apple"

# 디렉터리가 없는 경우 생성
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# 이미지 파일 처리 (파일명 알파벳순 정렬)
file_list = sorted(os.listdir(source_directory))
processed_count = 0  # 처리한 이미지 수를 추적하기 위한 변수

# 필요한 이미지 수가 채워질 때까지 루프 실행
while processed_count < 185:
    for filename in file_list:
        if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
            image_path = os.path.join(source_directory, filename)
            image = cv2.imread(image_path)

            if image is None:
                print(f"Warning: Unable to read image {filename}. Skipping.")
                continue

            # BGR 이미지를 HSV로 변환
            hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

            # 채도(Saturation) 조정 - 하나의 값(0.8)으로 조정
            hsv_image[:, :, 1] = hsv_image[:, :, 1] * 0.8  # Saturation 값 0.8로 설정

            # HSV 이미지를 다시 BGR로 변환
            adjusted_image = cv2.cvtColor(hsv_image, cv2.COLOR_HSV2BGR)
            output_path = os.path.join(output_directory, f"{os.path.splitext(filename)[0]}_saturation_adjusted_{processed_count}.png")
            cv2.imwrite(output_path, adjusted_image)

            processed_count += 1
            if processed_count >= 185:  # 185개의 이미지에 대해서만 처리
                break

print("Saturation adjustment completed for 185 images.")
# Out:
# Saturation adjustment completed for 185 images.

# %% [markdown]
# #### **rotten orange**

# %%
# 밝기 조절
# min_factor=0.9, max_factor=1.2

import Augmentor
import os

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/rotten orange", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/Brightness Adjustment rotten orange")

# 밝기 조절을 추가
# min_factor: 최소 밝기 조정값 (1.0보다 작으면 더 어두워짐)
# max_factor: 최대 밝기 조정값 (1.0보다 크면 더 밝아짐)
p.random_brightness(probability=1.0, min_factor=0.9, max_factor=1.2)

# 증강된 이미지를 185장 생성하여 저장
p.sample(185)
# Out:
# Initialised with 75 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/train/Brightness Adjustment rotten orange.
# Processing <PIL.Image.Image image mode=RGBA size=274x240 at 0x7C3374205A80>: 100%|██████████| 185/185 [00:02<00:00, 76.17 Samples/s]

# %%
# 대비 조절
# min_factor=0.8, max_factor=1.5

import Augmentor
import os

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/rotten orange", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/Contrast Adjustment rotten orange")

# 대비 조정을 추가
# min_factor: 최소 대비 조정값 (1.0보다 작으면 대비가 감소됨 ~> 흐릿한 이미지)
# max_factor: 최대 대비 조정값 (1.0보다 크면 대비가 증가됨 ~> 선명한 이미지)
p.random_contrast(probability=1.0, min_factor=0.8, max_factor=1.5)

# 증강된 이미지를 185장 생성하여 저장
p.sample(185)
# Out:
# Initialised with 75 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/train/Contrast Adjustment rotten orange.
# Processing <PIL.Image.Image image mode=RGBA size=492x422 at 0x7C33743B4940>: 100%|██████████| 185/185 [00:02<00:00, 83.29 Samples/s]

# %%
# 색상 조절
# min_factor=0.8, max_factor=1.2

import Augmentor
import os

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/rotten orange", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/train/Color Adjustment rotten orange")

# 대비 조정을 추가
# min_factor: 최소 대비 조정값 (1.0보다 작으면 대비가 감소됨 ~> 흐릿한 이미지)
# max_factor: 최대 대비 조정값 (1.0보다 크면 대비가 증가됨 ~> 선명한 이미지)
p.random_contrast(probability=1.0, min_factor=0.8, max_factor=1.2)

# 증강된 이미지를 370장 생성하여 저장
p.sample(370)
# Out:
# Initialised with 75 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/train/Color Adjustment rotten orange.
# Processing <PIL.Image.Image image mode=RGBA size=382x364 at 0x7C3374375EA0>: 100%|██████████| 370/370 [00:04<00:00, 85.31 Samples/s]

# %%
# 채도 조절
# 0.9

import cv2
import numpy as np
import os

# 이미지 파일이 있는 디렉터리를 지정
source_directory = "/content/drive/MyDrive/fruit_image_dataset/dataset/train/rotten orange"
output_directory = "/content/drive/MyDrive/fruit_image_dataset/dataset/train/Saturation Adjustment rotten orange"

# 디렉터리가 없는 경우 생성
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# 이미지 파일 처리 (파일명 알파벳순 정렬)
file_list = sorted(os.listdir(source_directory))
processed_count = 0  # 처리한 이미지 수를 추적하기 위한 변수

# 필요한 이미지 수가 채워질 때까지 루프 실행
while processed_count < 185:
    for filename in file_list:
        if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
            image_path = os.path.join(source_directory, filename)
            image = cv2.imread(image_path)

            if image is None:
                print(f"Warning: Unable to read image {filename}. Skipping.")
                continue

            # BGR 이미지를 HSV로 변환
            hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

            # 채도(Saturation) 조정 - 하나의 값(0.9)으로 조정
            hsv_image[:, :, 1] = hsv_image[:, :, 1] * 0.9  # Saturation 값 0.9로 설정

            # HSV 이미지를 다시 BGR로 변환
            adjusted_image = cv2.cvtColor(hsv_image, cv2.COLOR_HSV2BGR)
            output_path = os.path.join(output_directory, f"{os.path.splitext(filename)[0]}_saturation_adjusted_{processed_count}.png")
            cv2.imwrite(output_path, adjusted_image)

            processed_count += 1
            if processed_count >= 185:  # 185개의 이미지에 대해서만 처리
                break

print("Saturation adjustment completed for 185 images.")
# Out:
# Saturation adjustment completed for 185 images.

# %% [markdown]
# ### **2.1.2 validation**

# %% [markdown]
# #### **fresh apple**

# %%
# 밝기 조절
# min_factor=0.4, max_factor=0.6

import Augmentor
import os

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/val/fresh apple", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/val/Brightness Adjustment fresh apple")

# 만약 디렉터리가 없는 경우 생성
if not os.path.exists("/content/drive/MyDrive/fruit_image_dataset/dataset/val/Brightness Adjustment fresh apple"):
    os.makedirs("/content/drive/MyDrive/fruit_image_dataset/dataset/val/Brightness Adjustment fresh apple")

# 밝기 조절을 추가
# min_factor: 최소 밝기 조정값 (1.0보다 작으면 더 어두워짐)
# max_factor: 최대 밝기 조정값 (1.0보다 크면 더 밝아짐)
p.random_brightness(probability=1.0, min_factor=0.4, max_factor=0.6)

# 증강된 이미지를 70장 생성하여 저장
p.sample(70)
# Out:
# Initialised with 25 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/val/Brightness Adjustment fresh apple.
# Processing <PIL.Image.Image image mode=RGB size=346x382 at 0x786F04BEEDD0>: 100%|██████████| 70/70 [00:00<00:00, 98.99 Samples/s]

# %%
# 대비 조절
# min_factor=0.8, max_factor=1.5

import Augmentor
import os

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/val/fresh apple", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/val/Contrast Adjustment fresh apple")

# 만약 디렉터리가 없는 경우 생성
if not os.path.exists("/content/drive/MyDrive/fruit_image_dataset/dataset/val/Contrast Adjustment fresh apple"):
    os.makedirs("/content/drive/MyDrive/fruit_image_dataset/dataset/val/Contrast Adjustment fresh apple")

# 대비 조정을 추가
# min_factor: 최소 대비 조정값 (1.0보다 작으면 대비가 감소됨 ~> 흐릿한 이미지)
# max_factor: 최대 대비 조정값 (1.0보다 크면 대비가 증가됨 ~> 선명한 이미지)
p.random_contrast(probability=1.0, min_factor=0.8, max_factor=1.5)

# 증강된 이미지를 35장 생성하여 저장
p.sample(35)
# Out:
# Initialised with 25 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/val/Contrast Adjustment fresh apple.
# Processing <PIL.Image.Image image mode=RGB size=258x286 at 0x786F04B75EA0>: 100%|██████████| 35/35 [00:00<00:00, 88.89 Samples/s]

# %%
# 색상 조절
# min_factor=0.7, max_factor=0.8

import Augmentor
import os

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/val/fresh apple", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/val/Color Adjustment fresh apple")

# 만약 디렉터리가 없는 경우 생성
if not os.path.exists("/content/drive/MyDrive/fruit_image_dataset/dataset/val/Color Adjustment fresh apple"):
    os.makedirs("/content/drive/MyDrive/fruit_image_dataset/dataset/val/Color Adjustment fresh apple")

# 대비 조정을 추가
# min_factor: 최소 대비 조정값 (1.0보다 작으면 대비가 감소됨 ~> 흐릿한 이미지)
# max_factor: 최대 대비 조정값 (1.0보다 크면 대비가 증가됨 ~> 선명한 이미지)
p.random_contrast(probability=1.0, min_factor=0.7, max_factor=0.8)

# 증강된 이미지를 35장 생성하여 저장
p.sample(35)
# Out:
# Initialised with 25 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/val/Color Adjustment fresh apple.
# Processing <PIL.Image.Image image mode=RGB size=206x210 at 0x786F07CD9F00>: 100%|██████████| 35/35 [00:00<00:00, 88.59 Samples/s]

# %%
# 채도 조절
# 0.8

import cv2
import numpy as np
import os

# 이미지 파일이 있는 디렉터리를 지정
source_directory = "/content/drive/MyDrive/fruit_image_dataset/dataset/val/fresh apple"
output_directory = "/content/drive/MyDrive/fruit_image_dataset/dataset/val/Saturation Adjustment fresh apple"

# 디렉터리가 없는 경우 생성
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# 이미지 파일 처리 (파일명 알파벳순 정렬)
file_list = sorted(os.listdir(source_directory))
processed_count = 0  # 처리한 이미지 수를 추적하기 위한 변수

# 필요한 이미지 수가 채워질 때까지 루프 실행
while processed_count < 35:
    for filename in file_list:
        if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
            image_path = os.path.join(source_directory, filename)
            image = cv2.imread(image_path)

            if image is None:
                print(f"Warning: Unable to read image {filename}. Skipping.")
                continue

            # BGR 이미지를 HSV로 변환
            hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

            # 채도(Saturation) 조정 - 하나의 값(0.8)으로 조정
            hsv_image[:, :, 1] = hsv_image[:, :, 1] * 0.8  # Saturation 값 0.8로 설정

            # HSV 이미지를 다시 BGR로 변환
            adjusted_image = cv2.cvtColor(hsv_image, cv2.COLOR_HSV2BGR)
            output_path = os.path.join(output_directory, f"{os.path.splitext(filename)[0]}_saturation_adjusted_{processed_count}.png")
            cv2.imwrite(output_path, adjusted_image)

            processed_count += 1
            if processed_count >= 35:  # 35개의 이미지에 대해서만 처리
                break

print("Saturation adjustment completed for 35 images.")
# Out:
# Saturation adjustment completed for 35 images.

# %% [markdown]
# #### **fresh orange**

# %%
# 밝기 조절
# min_factor=0.9, max_factor=1.2

import Augmentor
import os

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/val/fresh orange", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/val/Brightness Adjustment fresh orange")

# 밝기 조절을 추가
# min_factor: 최소 밝기 조정값 (1.0보다 작으면 더 어두워짐)
# max_factor: 최대 밝기 조정값 (1.0보다 크면 더 밝아짐)
p.random_brightness(probability=1.0, min_factor=0.9, max_factor=1.2)

# 증강된 이미지를 35장 생성하여 저장
p.sample(35)
# Out:
# Initialised with 25 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/val/Brightness Adjustment fresh orange.
# Processing <PIL.Image.Image image mode=RGB size=326x316 at 0x7C33743B6FE0>: 100%|██████████| 35/35 [00:00<00:00, 46.87 Samples/s]

# %%
# 대비 조절
# min_factor=0.8, max_factor=1.5

import Augmentor
import os

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/val/fresh orange", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/val/Contrast Adjustment fresh orange")

# 대비 조정을 추가
# min_factor: 최소 대비 조정값 (1.0보다 작으면 대비가 감소됨 ~> 흐릿한 이미지)
# max_factor: 최대 대비 조정값 (1.0보다 크면 대비가 증가됨 ~> 선명한 이미지)
p.random_contrast(probability=1.0, min_factor=0.8, max_factor=1.5)

# 증강된 이미지를 35장 생성하여 저장
p.sample(35)
# Out:
# Initialised with 25 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/val/Contrast Adjustment fresh orange.
# Processing <PIL.Image.Image image mode=RGB size=440x434 at 0x7C337415A500>: 100%|██████████| 35/35 [00:00<00:00, 60.91 Samples/s]

# %%
# 색상 조절
# min_factor=0.8, max_factor=1.2

import Augmentor
import os

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/val/fresh orange", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/val/Color Adjustment fresh orange")

# 대비 조정을 추가
# min_factor: 최소 대비 조정값 (1.0보다 작으면 대비가 감소됨 ~> 흐릿한 이미지)
# max_factor: 최대 대비 조정값 (1.0보다 크면 대비가 증가됨 ~> 선명한 이미지)
p.random_contrast(probability=1.0, min_factor=0.8, max_factor=1.2)

# 증강된 이미지를 70장 생성하여 저장
p.sample(70)
# Out:
# Initialised with 25 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/val/Color Adjustment fresh orange.
# Processing <PIL.Image.Image image mode=RGB size=208x202 at 0x7C3374375A20>: 100%|██████████| 70/70 [00:00<00:00, 97.83 Samples/s]

# %%
# 채도 조절
# 1.2

import cv2
import numpy as np
import os

# 이미지 파일이 있는 디렉터리를 지정
source_directory = "/content/drive/MyDrive/fruit_image_dataset/dataset/val/fresh orange"
output_directory = "/content/drive/MyDrive/fruit_image_dataset/dataset/val/Saturation Adjustment fresh orange"

# 디렉터리가 없는 경우 생성
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# 이미지 파일 처리 (파일명 알파벳순 정렬)
file_list = sorted(os.listdir(source_directory))
processed_count = 0  # 처리한 이미지 수를 추적하기 위한 변수

# 필요한 이미지 수가 채워질 때까지 루프 실행
while processed_count < 35:
    for filename in file_list:
        if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
            image_path = os.path.join(source_directory, filename)
            image = cv2.imread(image_path)

            if image is None:
                print(f"Warning: Unable to read image {filename}. Skipping.")
                continue

            # BGR 이미지를 HSV로 변환
            hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

            # 채도(Saturation) 조정 - 하나의 값(1.2)으로 조정
            hsv_image[:, :, 1] = hsv_image[:, :, 1] * 1.2  # Saturation 값 1.2로 설정

            # HSV 이미지를 다시 BGR로 변환
            adjusted_image = cv2.cvtColor(hsv_image, cv2.COLOR_HSV2BGR)
            output_path = os.path.join(output_directory, f"{os.path.splitext(filename)[0]}_saturation_adjusted_{processed_count}.png")
            cv2.imwrite(output_path, adjusted_image)

            processed_count += 1
            if processed_count >= 35:  # 35개의 이미지에 대해서만 처리
                break

print("Saturation adjustment completed for 35 images.")
# Out:
# Saturation adjustment completed for 35 images.

# %% [markdown]
# #### **rotten apple**

# %%
# 밝기 조절
# min_factor=0.4, max_factor=0.6

import Augmentor
import os

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/val/rotten apple", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/val/Brightness Adjustment rotten apple")

# 만약 디렉터리가 없는 경우 생성
if not os.path.exists("/content/drive/MyDrive/fruit_image_dataset/dataset/val/Brightness Adjustment rotten apple"):
    os.makedirs("/content/drive/MyDrive/fruit_image_dataset/dataset/val/Brightness Adjustment rotten apple")

# 밝기 조절을 추가
# min_factor: 최소 밝기 조정값 (1.0보다 작으면 더 어두워짐)
# max_factor: 최대 밝기 조정값 (1.0보다 크면 더 밝아짐)
p.random_brightness(probability=1.0, min_factor=0.4, max_factor=0.6)

# 증강된 이미지를 70장 생성하여 저장
p.sample(70)
# Out:
# Initialised with 25 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/val/Brightness Adjustment rotten apple.
# Processing <PIL.Image.Image image mode=RGBA size=322x264 at 0x7E7F3C1F1630>: 100%|██████████| 70/70 [00:00<00:00, 93.28 Samples/s]

# %%
# 대비 조절
# min_factor=0.8, max_factor=1.5

import Augmentor
import os

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/val/rotten apple", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/val/Contrast Adjustment rotten apple")

# 만약 디렉터리가 없는 경우 생성
if not os.path.exists("/content/drive/MyDrive/fruit_image_dataset/dataset/val/Contrast Adjustment rotten apple"):
    os.makedirs("/content/drive/MyDrive/fruit_image_dataset/dataset/val/Contrast Adjustment rotten apple")

# 대비 조정을 추가
# min_factor: 최소 대비 조정값 (1.0보다 작으면 대비가 감소됨 ~> 흐릿한 이미지)
# max_factor: 최대 대비 조정값 (1.0보다 크면 대비가 증가됨 ~> 선명한 이미지)
p.random_contrast(probability=1.0, min_factor=0.8, max_factor=1.5)

# 증강된 이미지를 35장 생성하여 저장
p.sample(35)
# Out:
# Initialised with 25 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/val/Contrast Adjustment rotten apple.
# Processing <PIL.Image.Image image mode=RGBA size=480x418 at 0x7E7F1FF1C4F0>: 100%|██████████| 35/35 [00:00<00:00, 83.27 Samples/s]

# %%
# 색상 조절
# min_factor=0.7, max_factor=0.8

import Augmentor
import os

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/val/rotten apple", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/val/Color Adjustment rotten apple")

# 만약 디렉터리가 없는 경우 생성
if not os.path.exists("/content/drive/MyDrive/fruit_image_dataset/dataset/val/Color Adjustment rotten apple"):
    os.makedirs("/content/drive/MyDrive/fruit_image_dataset/dataset/val/Color Adjustment rotten apple")

# 대비 조정을 추가
# min_factor: 최소 대비 조정값 (1.0보다 작으면 대비가 감소됨 ~> 흐릿한 이미지)
# max_factor: 최대 대비 조정값 (1.0보다 크면 대비가 증가됨 ~> 선명한 이미지)
p.random_contrast(probability=1.0, min_factor=0.7, max_factor=0.8)

# 증강된 이미지를 35장 생성하여 저장
p.sample(35)
# Out:
# Initialised with 25 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/val/Color Adjustment rotten apple.
# Processing <PIL.Image.Image image mode=RGBA size=392x352 at 0x7E7F1FF36530>: 100%|██████████| 35/35 [00:00<00:00, 80.67 Samples/s]

# %%
# 채도 조절
# 0.8

import cv2
import numpy as np
import os

# 이미지 파일이 있는 디렉터리를 지정
source_directory = "/content/drive/MyDrive/fruit_image_dataset/dataset/val/rotten apple"
output_directory = "/content/drive/MyDrive/fruit_image_dataset/dataset/val/Saturation Adjustment rotten apple"

# 디렉터리가 없는 경우 생성
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# 이미지 파일 처리 (파일명 알파벳순 정렬)
file_list = sorted(os.listdir(source_directory))
processed_count = 0  # 처리한 이미지 수를 추적하기 위한 변수

# 필요한 이미지 수가 채워질 때까지 루프 실행
while processed_count < 35:
    for filename in file_list:
        if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
            image_path = os.path.join(source_directory, filename)
            image = cv2.imread(image_path)

            if image is None:
                print(f"Warning: Unable to read image {filename}. Skipping.")
                continue

            # BGR 이미지를 HSV로 변환
            hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

            # 채도(Saturation) 조정 - 하나의 값(0.8)으로 조정
            hsv_image[:, :, 1] = hsv_image[:, :, 1] * 0.8  # Saturation 값 0.8로 설정

            # HSV 이미지를 다시 BGR로 변환
            adjusted_image = cv2.cvtColor(hsv_image, cv2.COLOR_HSV2BGR)
            output_path = os.path.join(output_directory, f"{os.path.splitext(filename)[0]}_saturation_adjusted_{processed_count}.png")
            cv2.imwrite(output_path, adjusted_image)

            processed_count += 1
            if processed_count >= 35:  # 35개의 이미지에 대해서만 처리
                break

print("Saturation adjustment completed for 35 images.")
# Out:
# Saturation adjustment completed for 35 images.

# %% [markdown]
# #### **rotten orange**

# %%
# 밝기 조절
# min_factor=0.9, max_factor=1.2

import Augmentor
import os

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/val/rotten orange", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/val/Brightness Adjustment rotten orange")

# 밝기 조절을 추가
# min_factor: 최소 밝기 조정값 (1.0보다 작으면 더 어두워짐)
# max_factor: 최대 밝기 조정값 (1.0보다 크면 더 밝아짐)
p.random_brightness(probability=1.0, min_factor=0.9, max_factor=1.2)

# 증강된 이미지를 35장 생성하여 저장
p.sample(35)
# Out:
# Initialised with 25 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/val/Brightness Adjustment rotten orange.
# Processing <PIL.Image.Image image mode=RGBA size=256x214 at 0x7C33742068C0>: 100%|██████████| 35/35 [00:00<00:00, 39.90 Samples/s]

# %%
# 대비 조절
# min_factor=0.8, max_factor=1.5

import Augmentor
import os

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/val/rotten orange", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/val/Contrast Adjustment rotten orange")

# 대비 조정을 추가
# min_factor: 최소 대비 조정값 (1.0보다 작으면 대비가 감소됨 ~> 흐릿한 이미지)
# max_factor: 최대 대비 조정값 (1.0보다 크면 대비가 증가됨 ~> 선명한 이미지)
p.random_contrast(probability=1.0, min_factor=0.8, max_factor=1.5)

# 증강된 이미지를 35장 생성하여 저장
p.sample(35)
# Out:
# Initialised with 25 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/val/Contrast Adjustment rotten orange.
# Processing <PIL.Image.Image image mode=RGB size=468x414 at 0x7C33743B69B0>: 100%|██████████| 35/35 [00:00<00:00, 56.20 Samples/s]

# %%
# 색상 조절
# min_factor=0.8, max_factor=1.2

import Augmentor
import os

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/val/rotten orange", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/val/Color Adjustment rotten orange")

# 대비 조정을 추가
# min_factor: 최소 대비 조정값 (1.0보다 작으면 대비가 감소됨 ~> 흐릿한 이미지)
# max_factor: 최대 대비 조정값 (1.0보다 크면 대비가 증가됨 ~> 선명한 이미지)
p.random_contrast(probability=1.0, min_factor=0.8, max_factor=1.2)

# 증강된 이미지를 70장 생성하여 저장
p.sample(70)
# Out:
# Initialised with 25 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/val/Color Adjustment rotten orange.
# Processing <PIL.Image.Image image mode=RGBA size=146x116 at 0x7C33742D43D0>: 100%|██████████| 70/70 [00:00<00:00, 92.34 Samples/s]

# %%
# 채도 조절
# 0.9

import cv2
import numpy as np
import os

# 이미지 파일이 있는 디렉터리를 지정
source_directory = "/content/drive/MyDrive/fruit_image_dataset/dataset/val/rotten orange"
output_directory = "/content/drive/MyDrive/fruit_image_dataset/dataset/val/Saturation Adjustment rotten orange"

# 디렉터리가 없는 경우 생성
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# 이미지 파일 처리 (파일명 알파벳순 정렬)
file_list = sorted(os.listdir(source_directory))
processed_count = 0  # 처리한 이미지 수를 추적하기 위한 변수

# 필요한 이미지 수가 채워질 때까지 루프 실행
while processed_count < 35:
    for filename in file_list:
        if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
            image_path = os.path.join(source_directory, filename)
            image = cv2.imread(image_path)

            if image is None:
                print(f"Warning: Unable to read image {filename}. Skipping.")
                continue

            # BGR 이미지를 HSV로 변환
            hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

            # 채도(Saturation) 조정 - 하나의 값(0.9)으로 조정
            hsv_image[:, :, 1] = hsv_image[:, :, 1] * 0.9  # Saturation 값 0.9로 설정

            # HSV 이미지를 다시 BGR로 변환
            adjusted_image = cv2.cvtColor(hsv_image, cv2.COLOR_HSV2BGR)
            output_path = os.path.join(output_directory, f"{os.path.splitext(filename)[0]}_saturation_adjusted_{processed_count}.png")
            cv2.imwrite(output_path, adjusted_image)

            processed_count += 1
            if processed_count >= 35:  # 35개의 이미지에 대해서만 처리
                break

print("Saturation adjustment completed for 35 images.")
# Out:
# Saturation adjustment completed for 35 images.

# %% [markdown]
# ### **train 데이터 이미지 파일 개수**

# %%
import os

# 디렉토리 경로 설정
train_dir = '/content/drive/MyDrive/fruit_image_dataset/dataset/train'

# 어노테이션 파일 및 이미지 파일 검사
def count_files(directory):
    num_images = 0
    num_json_annotations = 0
    num_coco_annotations = 0
    num_mean_std_files = 0

    for filename in os.listdir(directory):
        if filename.endswith('.json'):
            if 'coco' in filename:
                num_coco_annotations += 1
            elif 'mean_std' in filename:
                num_mean_std_files += 1
            else:
                num_json_annotations += 1
        else:
            num_images += 1

    return num_images, num_json_annotations, num_coco_annotations, num_mean_std_files

# Train 데이터 출력
print("Train data:")
for class_name in os.listdir(train_dir):
    class_path = os.path.join(train_dir, class_name)
    if os.path.isdir(class_path):
        num_images, num_json_annotations, num_coco_annotations, num_mean_std_files = count_files(class_path)
        print(f"{class_name}: {num_images} images, {num_json_annotations} annotation file in JSON, {num_coco_annotations} annotation file in COCO, {num_mean_std_files} file of mean and std")
# Out:
# Train data:
# rotten apple: 1000 images, 0 annotation file in JSON, 0 annotation file in COCO, 0 file of mean and std
# fresh orange: 1000 images, 0 annotation file in JSON, 0 annotation file in COCO, 0 file of mean and std
# rotten orange: 1000 images, 0 annotation file in JSON, 0 annotation file in COCO, 0 file of mean and std
# fresh apple: 1000 images, 0 annotation file in JSON, 0 annotation file in COCO, 0 file of mean and std

# %% [markdown]
# ### **val 데이터 이미지 파일 개수**

# %%
import os

# 디렉토리 경로 설정
train_dir = '/content/drive/MyDrive/fruit_image_dataset/dataset/val'

# 어노테이션 파일 및 이미지 파일 검사
def count_files(directory):
    num_images = 0
    num_json_annotations = 0
    num_coco_annotations = 0
    num_mean_std_files = 0

    for filename in os.listdir(directory):
        if filename.endswith('.json'):
            if 'coco' in filename:
                num_coco_annotations += 1
            elif 'mean_std' in filename:
                num_mean_std_files += 1
            else:
                num_json_annotations += 1
        else:
            num_images += 1

    return num_images, num_json_annotations, num_coco_annotations, num_mean_std_files

# Validation 데이터 출력
print("Validation data:")
for class_name in os.listdir(train_dir):
    class_path = os.path.join(train_dir, class_name)
    if os.path.isdir(class_path):
        num_images, num_json_annotations, num_coco_annotations, num_mean_std_files = count_files(class_path)
        print(f"{class_name}: {num_images} images, {num_json_annotations} annotation file in JSON, {num_coco_annotations} annotation file in COCO, {num_mean_std_files} file of mean and std")
# Out:
# Validation data:
# rotten apple: 200 images, 0 annotation file in JSON, 0 annotation file in COCO, 0 file of mean and std
# fresh apple: 200 images, 0 annotation file in JSON, 0 annotation file in COCO, 0 file of mean and std
# fresh orange: 200 images, 0 annotation file in JSON, 0 annotation file in COCO, 0 file of mean and std
# rotten orange: 200 images, 0 annotation file in JSON, 0 annotation file in COCO, 0 file of mean and std

# %% [markdown]
# ## **2.2 test 이미지들**

# %% [markdown]
# ### **fresh apple**

# %% [markdown]
# ### **fresh orange**

# %%
import Augmentor
import os

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/test/fresh orange", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/test/Augmented fresh orange")

# 좌우 대칭을 추가
# probability: 좌우 대칭이 적용될 확률 (1.0은 항상 적용됨)
p.flip_left_right(probability=1.0)

# 증강된 이미지를 87장 생성하여 저장
p.sample(87)

print("Left-right flip augmentation completed.")
# Out:
# Initialised with 3 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/test/Augmented fresh orange.
# Processing <PIL.Image.Image image mode=RGB size=3596x4795 at 0x79AC540BE0E0>: 100%|██████████| 87/87 [00:03<00:00, 24.46 Samples/s]
# Left-right flip augmentation completed.

# %% [markdown]
# ### **rotten apple**

# %% [markdown]
# ### **rotten orange**

# %%
import Augmentor
import os

# 이미지 파일이 있는 디렉터리를 지정
p = Augmentor.Pipeline(source_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/test/rotten orange", output_directory="/content/drive/MyDrive/fruit_image_dataset/dataset/test/Augmented rotten orange")

# 좌우 대칭을 추가
# probability: 좌우 대칭이 적용될 확률 (1.0은 항상 적용됨)
p.flip_left_right(probability=1.0)

# 증강된 이미지를 87장 생성하여 저장
p.sample(87)

print("Left-right flip augmentation completed.")
# Out:
# Initialised with 3 image(s) found.
# Output directory set to /content/drive/MyDrive/fruit_image_dataset/dataset/test/Augmented rotten orange.
# Processing <PIL.Image.Image image mode=RGB size=4032x3024 at 0x79AC540BD960>: 100%|██████████| 87/87 [00:03<00:00, 25.52 Samples/s]
# Left-right flip augmentation completed.

# %% [markdown]
# ## **test 데이터 이미지 파일 개수**

# %%
import os

# 디렉토리 경로 설정
train_dir = '/content/drive/MyDrive/fruit_image_dataset/dataset/test'

# 어노테이션 파일 및 이미지 파일 검사
def count_files(directory):
    num_images = 0
    num_json_annotations = 0
    num_coco_annotations = 0
    num_mean_std_files = 0

    for filename in os.listdir(directory):
        if filename.endswith('.json'):
            if 'coco' in filename:
                num_coco_annotations += 1
            elif 'mean_std' in filename:
                num_mean_std_files += 1
            else:
                num_json_annotations += 1
        else:
            num_images += 1

    return num_images, num_json_annotations, num_coco_annotations, num_mean_std_files

# Test 데이터 출력
print("Test data:")
for class_name in os.listdir(train_dir):
    class_path = os.path.join(train_dir, class_name)
    if os.path.isdir(class_path):
        num_images, num_json_annotations, num_coco_annotations, num_mean_std_files = count_files(class_path)
        print(f"{class_name}: {num_images} images, {num_json_annotations} annotation file in JSON, {num_coco_annotations} annotation file in COCO, {num_mean_std_files} file of mean and std")
# Out:
# Test data:
# rotten apple: 90 images, 0 annotation file in JSON, 0 annotation file in COCO, 0 file of mean and std
# fresh apple: 90 images, 0 annotation file in JSON, 0 annotation file in COCO, 0 file of mean and std
# fresh orange: 90 images, 0 annotation file in JSON, 0 annotation file in COCO, 0 file of mean and std
# rotten orange: 90 images, 0 annotation file in JSON, 0 annotation file in COCO, 0 file of mean and std

# %% [markdown]
# # **2. EfficientNet-B0** 모델 학습 과정 코드
# ---
# * 이미지 크기(img size) : 224x224
# * 배치 크기(batch size) : 32
# * 에포크(ephochs) : 50
# * 학습률(learning rate) : 0.001

# %% [markdown]
# ## **2.1 필요한 라이브러리 설치 & 임포트**

# %%
# TensorFlow 설치 (Colab에서는 보통 이미 설치되어 있지만, 최신 버전이 필요할 수 있음)
# !pip install -q tensorflow

# 필요한 라이브러리 임포트
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import Input, GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## **2.2 첫번째 모델 학습**

# %%
# GPU가 사용 가능한지 확인
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# 이미지를 리사이징하기 전에 패딩을 추가
def pad_to_square(img):
    old_size = tf.shape(img)[:2]
    desired_size = tf.reduce_max(old_size)
    delta_w = desired_size - old_size[1]
    delta_h = desired_size - old_size[0]
    top = delta_h // 2
    bottom = delta_h - top
    left = delta_w // 2
    right = delta_w - left
    new_img = tf.image.pad_to_bounding_box(img, top, left, desired_size, desired_size)
    new_img = tf.image.resize(new_img, (224, 224))  # 다시 224x224로 리사이즈
    return new_img

# 데이터 경로 설정
train_dir = '/content/drive/MyDrive/fruit_image_dataset/dataset/train'
val_dir = '/content/drive/MyDrive/fruit_image_dataset/dataset/val'
test_dir = '/content/drive/MyDrive/fruit_image_dataset/dataset/test'

# 이미지 데이터 전처리 (Train, Validation, Test에 대해 각각 생성)
train_datagen = ImageDataGenerator(
    rescale=1./255,  # 이미지 정규화
    preprocessing_function=pad_to_square  # 패딩을 추가하는 함수 적용
)

val_datagen = ImageDataGenerator(
    rescale=1./255,
    preprocessing_function=pad_to_square
)

test_datagen = ImageDataGenerator(
    rescale=1./255,
    preprocessing_function=pad_to_square
)

# 이미지를 로드하고 크기 조정
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),  # EfficientNetB0의 입력 크기
    batch_size=32,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

# Input 레이어 정의
input_tensor = Input(shape=(224, 224, 3))

# EfficientNetB0 모델 가져오기 (사전 학습된 가중치 사용)
base_model = EfficientNetB0(weights='imagenet', include_top=False, input_tensor=input_tensor)

# GlobalAveragePooling2D 및 Dense 레이어 추가
x = GlobalAveragePooling2D()(base_model.output)
output_tensor = Dense(4, activation='softmax')(x)

# 모델 정의
model = Model(inputs=input_tensor, outputs=output_tensor)

# 모델 컴파일
learning_rate = 0.001
model.compile(
    optimizer=Adam(learning_rate=learning_rate),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# 모델 저장을 위한 체크포인트 설정
checkpoint = ModelCheckpoint(
    '/content/drive/MyDrive/fruit_image_dataset/dataset/efficientnet_b0_best_model.keras',  # 모델이 저장될 경로
    monitor='val_loss',  # Validation loss를 모니터링
    save_best_only=True,  # 가장 좋은 성능을 보인 모델만 저장
    mode='min',  # Validation loss가 최소일 때 저장
    verbose=1
)

# 조기 종료 설정
early_stopping = EarlyStopping(
    monitor='val_loss',  # Validation loss를 모니터링
    patience=5,  # 성능 개선이 없을 때의 에포크 수
    restore_best_weights=True  # 성능이 가장 좋았던 가중치로 복원
)

# 모델 학습
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=val_generator,
    callbacks=[early_stopping, checkpoint],  # 조기 종료 및 체크포인트 콜백 추가
    batch_size=32
)
# Out:
# Num GPUs Available:  1
# Found 4000 images belonging to 4 classes.
# Found 800 images belonging to 4 classes.
# Found 360 images belonging to 4 classes.
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 124/125 ━━━━━━━━━━━━━━━━━━━━ 13s 14s/step - accuracy: 0.9211 - loss: 0.2116
# Epoch 1: val_loss improved from inf to 4.66997, saving model to /content/drive/MyDrive/fruit_image_dataset/dataset/efficientnet_b0_best_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2391s 18s/step - accuracy: 0.9218 - loss: 0.2098 - val_accuracy: 0.2500 - val_loss: 4.6700
# Epoch 2/50
# 124/125 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step - accuracy: 0.9906 - loss: 0.0275
# Epoch 2: val_loss improved from 4.66997 to 2.78138, saving model to /content/drive/MyDrive/fruit_image_dataset/dataset/efficientnet_b0_best_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 68s 518ms/step - accuracy: 0.9906 - loss: 0.0274 - val_accuracy: 0.2500 - val_loss: 2.7814
# Epoch 3/50
# 124/125 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - accuracy: 0.9976 - loss: 0.0105
# Epoch 3: val_loss did not improve from 2.78138
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 66s 508ms/step - accuracy: 0.9976 - loss: 0.0104 - val_accuracy: 0.2500 - val_loss: 10.0110
# Epoch 4/50
# 124/125 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - accuracy: 0.9945 - loss: 0.0164
# Epoch 4: val_loss improved from 2.78138 to 1.95438, saving model to /content/drive/MyDrive/fruit_image_dataset/dataset/efficientnet_b0_best_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 68s 521ms/step - accuracy: 0.9945 - loss: 0.0165 - val_accuracy: 0.5000 - val_loss: 1.9544
# Epoch 5/50
# 124/125 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - accuracy: 0.9925 - loss: 0.0255
# Epoch 5: val_loss improved from 1.95438 to 0.55406, saving model to /content/drive/MyDrive/fruit_image_dataset/dataset/efficientnet_b0_best_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 68s 517ms/step - accuracy: 0.9925 - loss: 0.0255 - val_accuracy: 0.7563 - val_loss: 0.5541
# Epoch 6/50
# 124/125 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.9995 - loss: 0.0069
# Epoch 6: val_loss improved from 0.55406 to 0.47781, saving model to /content/drive/MyDrive/fruit_image_dataset/dataset/efficientnet_b0_best_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 67s 515ms/step - accuracy: 0.9994 - loss: 0.0070 - val_accuracy: 0.8587 - val_loss: 0.4778
# Epoch 7/50
# 124/125 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.9956 - loss: 0.0159
# Epoch 7: val_loss did not improve from 0.47781
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 66s 506ms/step - accuracy: 0.9956 - loss: 0.0159 - val_accuracy: 0.8275 - val_loss: 0.6332
# Epoch 8/50
# 124/125 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step - accuracy: 0.9835 - loss: 0.0480
# Epoch 8: val_loss improved from 0.47781 to 0.24100, saving model to /content/drive/MyDrive/fruit_image_dataset/dataset/efficientnet_b0_best_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 67s 517ms/step - accuracy: 0.9837 - loss: 0.0476 - val_accuracy: 0.9013 - val_loss: 0.2410
# Epoch 9/50
# 124/125 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - accuracy: 0.9904 - loss: 0.0305
# Epoch 9: val_loss did not improve from 0.24100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 67s 510ms/step - accuracy: 0.9904 - loss: 0.0305 - val_accuracy: 0.9087 - val_loss: 0.2559
# Epoch 10/50
# 124/125 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - accuracy: 0.9974 - loss: 0.0078
# Epoch 10: val_loss improved from 0.24100 to 0.01443, saving model to /content/drive/MyDrive/fruit_image_dataset/dataset/efficientnet_b0_best_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 68s 517ms/step - accuracy: 0.9974 - loss: 0.0078 - val_accuracy: 0.9975 - val_loss: 0.0144
# Epoch 11/50
# 124/125 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step - accuracy: 1.0000 - loss: 5.8798e-04
# Epoch 11: val_loss improved from 0.01443 to 0.00955, saving model to /content/drive/MyDrive/fruit_image_dataset/dataset/efficientnet_b0_best_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 68s 517ms/step - accuracy: 1.0000 - loss: 5.8475e-04 - val_accuracy: 0.9987 - val_loss: 0.0096
# Epoch 12/50
# 124/125 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 1.0000 - loss: 7.4452e-05
# Epoch 12: val_loss did not improve from 0.00955
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 66s 505ms/step - accuracy: 1.0000 - loss: 7.4961e-05 - val_accuracy: 0.9987 - val_loss: 0.0103
# Epoch 13/50
# 124/125 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 1.0000 - loss: 7.1019e-05
# Epoch 13: val_loss did not improve from 0.00955
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 66s 506ms/step - accuracy: 1.0000 - loss: 8.4065e-05 - val_accuracy: 0.9762 - val_loss: 0.0658
# Epoch 14/50
# 124/125 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step - accuracy: 0.9990 - loss: 0.0027
# Epoch 14: val_loss did not improve from 0.00955
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 67s 509ms/step - accuracy: 0.9990 - loss: 0.0027 - val_accuracy: 0.9875 - val_loss: 0.0295
# Epoch 15/50
# 124/125 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 1.0000 - loss: 1.5524e-04
# Epoch 15: val_loss did not improve from 0.00955
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 66s 506ms/step - accuracy: 1.0000 - loss: 1.5453e-04 - val_accuracy: 1.0000 - val_loss: 0.0116
# Epoch 16/50
# 124/125 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 1.0000 - loss: 6.3400e-05
# Epoch 16: val_loss improved from 0.00955 to 0.00860, saving model to /content/drive/MyDrive/fruit_image_dataset/dataset/efficientnet_b0_best_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 67s 513ms/step - accuracy: 1.0000 - loss: 6.4108e-05 - val_accuracy: 1.0000 - val_loss: 0.0086
# Epoch 17/50
# 124/125 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step - accuracy: 1.0000 - loss: 3.7678e-05
# Epoch 17: val_loss improved from 0.00860 to 0.00612, saving model to /content/drive/MyDrive/fruit_image_dataset/dataset/efficientnet_b0_best_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 67s 516ms/step - accuracy: 1.0000 - loss: 3.7576e-05 - val_accuracy: 1.0000 - val_loss: 0.0061
# Epoch 18/50
# 124/125 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - accuracy: 1.0000 - loss: 2.5299e-05
# Epoch 18: val_loss did not improve from 0.00612
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 66s 509ms/step - accuracy: 1.0000 - loss: 2.5252e-05 - val_accuracy: 1.0000 - val_loss: 0.0063
# Epoch 19/50
# 124/125 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 1.0000 - loss: 2.6063e-05
# Epoch 19: val_loss improved from 0.00612 to 0.00412, saving model to /content/drive/MyDrive/fruit_image_dataset/dataset/efficientnet_b0_best_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 67s 515ms/step - accuracy: 1.0000 - loss: 2.6225e-05 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 20/50
# 124/125 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - accuracy: 1.0000 - loss: 2.0743e-05
# Epoch 20: val_loss did not improve from 0.00412
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 66s 508ms/step - accuracy: 1.0000 - loss: 2.0915e-05 - val_accuracy: 1.0000 - val_loss: 0.0061
# Epoch 21/50
# 124/125 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step - accuracy: 1.0000 - loss: 2.6201e-05
# Epoch 21: val_loss did not improve from 0.00412
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 66s 507ms/step - accuracy: 1.0000 - loss: 2.6166e-05 - val_accuracy: 1.0000 - val_loss: 0.0060
# Epoch 22/50
# 124/125 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 1.0000 - loss: 2.1597e-05
# Epoch 22: val_loss did not improve from 0.00412
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 66s 504ms/step - accuracy: 1.0000 - loss: 2.1545e-05 - val_accuracy: 1.0000 - val_loss: 0.0067
# Epoch 23/50
# 124/125 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - accuracy: 1.0000 - loss: 9.9027e-06
# Epoch 23: val_loss did not improve from 0.00412
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 66s 508ms/step - accuracy: 1.0000 - loss: 9.9078e-06 - val_accuracy: 1.0000 - val_loss: 0.0064
# Epoch 24/50
# 124/125 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 1.0000 - loss: 1.8853e-05
# Epoch 24: val_loss did not improve from 0.00412
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 66s 503ms/step - accuracy: 1.0000 - loss: 1.8833e-05 - val_accuracy: 0.9987 - val_loss: 0.0069

# %% [markdown]
# ### *파일 이름 정리*

# %%
import os

train_dir = '/content/drive/MyDrive/fruit_image_dataset/dataset/train'

# 지원되지 않는 확장자를 가진 파일들의 개수를 세기 위한 변수
unsupported_file_count = 0

for root, dirs, files in os.walk(train_dir):
    for file in files:
        if not file.lower().endswith(('.png', '.jpg', '.jpeg')):
            print(f"Non-supported file found: {file}")
            unsupported_file_count += 1  # 지원되지 않는 파일의 개수 증가

# 최종적으로 지원되지 않는 파일들의 개수를 출력
print(f"Total number of non-supported files: {unsupported_file_count}")
# Out:
# Total number of non-supported files: 0

# %%
import os

train_dir = '/content/drive/MyDrive/fruit_image_dataset/dataset/train'

# 디렉토리 내 모든 파일 탐색
for root, dirs, files in os.walk(train_dir):
    for file in files:
        # 파일명을 출력하여 실제로 탐색된 파일들을 확인
        print(f"Found file: {file}")

        # 파일명이 '.png'로 끝나지 않고 추가적인 텍스트가 붙어 있는 경우 처리
        if '.png' in file.lower() and not file.lower().endswith('.png'):
            # 새로운 파일명 생성
            new_file_name = file.lower().split('.png')[0] + '.png'
            old_file_path = os.path.join(root, file)
            new_file_path = os.path.join(root, new_file_name)

            # 파일명 변경
            os.rename(old_file_path, new_file_path)
            print(f"Renamed: {file} -> {new_file_name}")
# Out:
# Found file: Screen Shot 2018-06-07 at 2.23.40 PM.png
# Found file: Screen Shot 2018-06-07 at 2.19.46 PM.png
# Found file: Screen Shot 2018-06-07 at 2.24.02 PM.png
# Found file: Screen Shot 2018-06-07 at 2.15.20 PM.png
# Found file: Screen Shot 2018-06-07 at 2.23.24 PM.png
# Found file: Screen Shot 2018-06-07 at 2.17.25 PM.png
# Found file: Screen Shot 2018-06-07 at 2.23.51 PM.png
# Found file: Screen Shot 2018-06-07 at 2.19.37 PM.png
# Found file: Screen Shot 2018-06-07 at 2.23.02 PM.png
# Found file: Screen Shot 2018-06-07 at 2.17.15 PM.png
# Found file: Screen Shot 2018-06-07 at 2.18.13 PM.png
# Found file: Screen Shot 2018-06-07 at 2.16.41 PM.png
# Found file: Screen Shot 2018-06-07 at 2.19.15 PM.png
# Found file: Screen Shot 2018-06-07 at 2.18.57 PM.png
# Found file: Screen Shot 2018-06-07 at 2.16.18 PM.png
# Found file: Screen Shot 2018-06-07 at 2.15.50 PM.png
# Found file: Screen Shot 2018-06-07 at 2.22.00 PM.png
# Found file: Screen Shot 2018-06-07 at 2.31.43 PM.png
# Found file: Screen Shot 2018-06-07 at 2.24.47 PM.png
# Found file: Screen Shot 2018-06-07 at 2.25.16 PM.png
# Found file: Screen Shot 2018-06-07 at 2.31.59 PM.png
# Found file: Screen Shot 2018-06-07 at 2.42.58 PM.png
# Found file: Screen Shot 2018-06-07 at 2.43.13 PM.png
# Found file: Screen Shot 2018-06-07 at 2.37.11 PM.png
# Found file: Screen Shot 2018-06-07 at 2.37.43 PM.png
# Found file: Screen Shot 2018-06-07 at 2.33.38 PM.png
# Found file: Screen Shot 2018-06-07 at 2.40.55 PM.png
# Found file: Screen Shot 2018-06-07 at 2.40.28 PM.png
# Found file: Screen Shot 2018-06-07 at 2.35.10 PM.png
# Found file: Screen Shot 2018-06-07 at 2.33.47 PM.png
# Found file: Screen Shot 2018-06-07 at 2.41.32 PM.png
# Found file: Screen Shot 2018-06-07 at 2.42.25 PM.png
# Found file: Screen Shot 2018-06-07 at 2.43.26 PM.png
# Found file: Screen Shot 2018-06-07 at 2.41.07 PM.png
# Found file: Screen Shot 2018-06-07 at 2.40.48 PM.png
# Found file: Screen Shot 2018-06-07 at 2.24.35 PM.png
# Found file: Screen Shot 2018-06-07 at 2.38.28 PM.png
# Found file: Screen Shot 2018-06-07 at 2.35.21 PM.png
# Found file: Screen Shot 2018-06-07 at 2.34.18 PM.png
# Found file: Screen Shot 2018-06-07 at 2.38.49 PM.png
# Found file: Screen Shot 2018-06-07 at 2.42.18 PM.png
# Found file: Screen Shot 2018-06-07 at 2.38.04 PM.png
# Found file: Screen Shot 2018-06-07 at 2.43.07 PM.png
# Found file: Screen Shot 2018-06-07 at 2.44.59 PM.png
# Found file: Screen Shot 2018-06-07 at 2.53.20 PM.png
# Found file: Screen Shot 2018-06-07 at 2.44.51 PM.png
# Found file: Screen Shot 2018-06-07 at 2.51.01 PM.png
# Found file: Screen Shot 2018-06-07 at 2.47.35 PM.png
# Found file: Screen Shot 2018-06-07 at 2.46.52 PM.png
# Found file: Screen Shot 2018-06-07 at 2.52.00 PM.png
# Found file: Screen Shot 2018-06-07 at 2.52.44 PM.png
# Found file: Screen Shot 2018-06-07 at 2.54.08 PM.png
# Found file: Screen Shot 2018-06-07 at 2.47.13 PM.png
# Found file: Screen Shot 2018-06-07 at 2.52.30 PM.png
# Found file: Screen Shot 2018-06-07 at 2.43.54 PM.png
# Found file: Screen Shot 2018-06-07 at 2.52.09 PM.png
# Found file: Screen Shot 2018-06-07 at 2.50.31 PM.png
# Found file: Screen Shot 2018-06-07 at 2.53.33 PM.png
# Found file: Screen Shot 2018-06-07 at 2.52.22 PM.png
# Found file: Screen Shot 2018-06-07 at 2.55.27 PM.png
# Found file: Screen Shot 2018-06-07 at 2.47.20 PM.png
# Found file: Screen Shot 2018-06-07 at 2.45.35 PM.png
# Found file: Screen Shot 2018-06-07 at 2.54.58 PM.png
# Found file: Screen Shot 2018-06-07 at 2.47.27 PM.png
# Found file: Screen Shot 2018-06-07 at 2.54.49 PM.png
# Found file: Screen Shot 2018-06-07 at 2.57.13 PM.png
# Found file: Screen Shot 2018-06-07 at 2.57.17 PM.png
# Found file: Screen Shot 2018-06-07 at 2.57.05 PM.png
# Found file: Screen Shot 2018-06-07 at 2.59.52 PM.png
# Found file: Screen Shot 2018-06-07 at 2.58.57 PM.png
# Found file: Screen Shot 2018-06-07 at 2.59.38 PM.png
# Found file: Screen Shot 2018-06-07 at 2.57.26 PM.png
# Found file: Screen Shot 2018-06-07 at 2.56.34 PM.png
# Found file: Screen Shot 2018-06-07 at 3.00.17 PM.png
# Found file: Screen Shot 2018-06-07 at 3.17.25 PM.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.54.58 PM.png_bbbe5f00-0b25-4b47-aa94-6a2dd4866f02.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.37.43 PM.png_81760e6f-f7b0-4d16-8ce8-68dbee8fe594.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.57.05 PM.png_8d1827b9-f972-482b-bbec-85c0c0bebd8e.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.17.15 PM.png_2878b22c-ee76-4238-983f-18916b71e20a.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 3.17.25 PM.png_b2f0055f-b05e-42be-a1c9-0c165d69229f.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.42.25 PM.png_758a8b71-61f5-46a1-a752-b32d08f23411.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.44.51 PM.png_8dc2165b-97dd-4c57-a4bf-e172ea7788f1.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.35.10 PM.png_9971c62a-6d09-433a-a51f-d742531e46e7.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.38.04 PM.png_22b39f14-a945-4e01-965e-b2eaa75929b6.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.15.20 PM.png_0a7933e7-93bc-4d24-b320-531e600592f3.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.37.11 PM.png_d8007c76-2d09-4829-b570-cf7478cb2704.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.52.44 PM.png_58690a3c-2cea-4936-86aa-fe7ab1ffb9ec.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.59.52 PM.png_2350dd8e-aa15-48e2-8f56-48000cb74bd6.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.59.52 PM.png_1017fcb8-1a45-46bb-9980-736215c11bae.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.38.04 PM.png_7a5948bf-abe4-4f2d-a021-e1c137cc37d3.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.43.26 PM.png_48bc2358-b259-4fcd-9821-9f02489b0520.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.41.07 PM.png_bef597d4-7e96-4f97-a909-9f5a34a12d62.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.16.18 PM.png_76f216e4-f7e1-4737-92b3-5e15bf44efde.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.47.20 PM.png_b7247eb5-8e05-465d-be76-4daa39ab9ef7.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.33.38 PM.png_e52c34ba-3313-41e0-b424-52d781b50efb.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.18.13 PM.png_cc72e36d-1433-475d-ad3b-8ff7a6b1dd15.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.25.16 PM.png_05797675-2c3a-4ac1-8d65-013c9f83a10a.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.15.20 PM.png_2312bafe-a1b7-407b-8908-887d5e48e5bd.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.47.13 PM.png_9cbcc4d0-7b0e-4b34-8308-c7abdede7fae.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.38.04 PM.png_d2cc9c7c-fc4b-4267-b6ab-3908321136ff.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.58.57 PM.png_4d78997c-6fb2-4276-b55a-d08cbaecd091.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.56.34 PM.png_ef420aca-3508-427e-8dba-145aee6c86ba.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.47.27 PM.png_747335c1-cabd-425e-a7bf-ef1e86b9f7a4.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.58.57 PM.png_e79a292f-4162-4c42-ae53-4f9d7e46d539.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.40.28 PM.png_a14ca73c-3e60-4c36-a062-6ba14a7742d9.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.41.32 PM.png_80acdb77-8560-457c-a81d-0a4728006f78.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.24.02 PM.png_94a11620-715c-4d59-b613-dae1acc74abf.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.52.00 PM.png_787c2927-330e-4386-b75c-966224a3b705.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.31.59 PM.png_054ac4ad-36fb-4e82-8a1e-9f6ebd71429e.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.34.18 PM.png_2e2f7d4d-29df-48ad-9374-05c00d286b5b.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.40.28 PM.png_f34fa72d-e4d1-4f1a-b6cb-58069b88c039.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.43.13 PM.png_f5680215-ac46-4545-8e48-66a45cf3f61f.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.24.35 PM.png_5409e574-23b3-4705-9071-b6a563217a96.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.42.18 PM.png_1a2fa073-e82b-4f9a-bf8a-e028cf8d81cf.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.45.35 PM.png_1e55b109-56da-406a-bb11-29ae74d15c3a.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.33.38 PM.png_546e36ec-4648-4468-958b-0a57aada5839.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.47.20 PM.png_cc18e1b8-1e80-4230-a605-64f0dbf0f5ea.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.44.59 PM.png_0f8a657d-3059-40d8-8057-c4f39d2ed66c.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.45.35 PM.png_234bf499-4ce9-4253-b6e0-188225c5a874.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.44.51 PM.png_6c531bb6-94dc-48f6-bb09-9cab209fa0ad.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.19.46 PM.png_114da114-d654-44e5-8200-7ad09d3ec862.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.43.07 PM.png_e9b040fd-1835-44a2-85e0-a98472c3dab9.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 3.00.17 PM.png_b3b1417d-d4fb-4c8c-8eff-62ea74d239ea.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.41.07 PM.png_8aecf238-7e41-44b3-8e0d-6b0b946d450f.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.16.41 PM.png_3229b8ed-d2bd-41f7-a0d9-cfc3f03c3aea.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.35.10 PM.png_d07835c2-04b8-45d2-a547-e1cf0b677437.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.41.32 PM.png_4604460b-4904-4b43-8fc5-6d1d4f4ae0e1.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.43.54 PM.png_40ac69fd-11a3-4a93-823a-06c8ca24219f.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.52.44 PM.png_29fa71ca-180d-4920-8ef5-970f2c6d8c8a.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.37.43 PM.png_bb4f12c8-2c91-4534-82ab-6ff54874fa6e.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.44.59 PM.png_44660df5-d04f-4140-b976-e4db70735f03.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 3.17.25 PM.png_a13fed8b-1e32-4f42-bc0f-ca33beae62d7.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.16.18 PM.png_d0edd882-3241-4248-9afa-e663c9fe644d.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.25.16 PM.png_b9dc7616-402d-4491-b42c-fa74f9ab5087.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.17.25 PM.png_ba77a500-42f2-4a5c-8eff-532206c84d85.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.16.18 PM.png_c09ee790-6332-4217-a131-8845c095ab25.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.43.07 PM.png_8ab35301-483a-4b8b-9e95-a4cc582493ce.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.46.52 PM.png_c85f1e42-8c1e-49c5-b61f-9903f3fefe9a.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.38.28 PM.png_b52b6f96-92af-401c-a8e4-bc9269b67b7a.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.59.52 PM.png_e53ec597-a12a-4598-b2f5-a56d09a1193c.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.54.49 PM.png_340852cc-e76e-4704-9ddf-6bbcc5c2cde7.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.43.54 PM.png_efd316bf-4cc6-4af5-9e58-7cf9888be3b0.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.37.43 PM.png_041f00d3-b426-489e-85df-eb2b501f0b71.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.17.25 PM.png_12d25503-525d-498a-adb4-bf5c73dbee3a.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.46.52 PM.png_bdca8c13-f952-46ec-9020-a8dde2f13377.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.19.46 PM.png_9b05ca60-15d1-4d65-affc-5f6e2fc92f95.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.38.04 PM.png_83720392-53f2-4d52-b19a-1f7cc0b184c5.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.15.50 PM.png_996e5230-6522-4a6c-ba26-ec185db0f1eb.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.52.22 PM.png_9f5b26f7-baeb-45c6-8063-4bb22e1bfc65.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.52.09 PM.png_4eba8d15-aa8d-4083-b706-221322763261.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.44.51 PM.png_6b392610-8b8f-4391-a0a4-b1255cb90860.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.53.20 PM.png_4f5d8bfa-e390-4a7c-b58d-0b856083cf17.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.25.16 PM.png_16a95822-ea29-400a-935e-c427764af0d4.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.46.52 PM.png_82a62611-b23f-4e24-8d23-98459dfcd60b.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.46.52 PM.png_1c39273a-78a0-48f4-93e7-5957e8b0f441.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.24.47 PM.png_5eb71230-e86a-4bc4-9c97-29977e0efa52.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.23.24 PM.png_17c45860-8d34-40fc-abc3-d484074e8c24.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.18.13 PM.png_1b35ca8b-d0d1-4c43-9835-95f01f743e6b.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.51.01 PM.png_92771400-26ef-4c84-9b17-eba0aac2bf6f.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.59.38 PM.png_4607c27a-e321-4052-950e-c82612b26312.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.42.18 PM.png_299dde75-2e3b-4a3d-b70d-9a2096ea87d4.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.43.26 PM.png_f14bfd79-c857-407d-9aeb-ea7ab55c8d51.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.22.00 PM.png_3de9db62-7aa8-4e3a-be71-4486042b2440.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.37.11 PM.png_93b1ad0d-492e-4162-9317-a2f861c66e0f.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.23.02 PM.png_9ed2c480-df2b-4dd7-b595-12e7d5f56253.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.45.35 PM.png_1b3589ed-08bc-44e6-bc65-7046b9b313d0.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.23.24 PM.png_35902567-7a70-4f7f-9727-81d2c8d76fd7.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.56.34 PM.png_3d0ec406-2a23-418b-8e5f-846de0f5e2f9.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.58.57 PM.png_344fe51c-4725-4b34-a0d8-9525c1edbea3.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.43.26 PM.png_3781d61d-6657-423e-b2a3-97813097ad7f.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.41.32 PM.png_6ee743f8-d083-4059-a864-6a84dd3e1fec.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.22.00 PM.png_8eb93ef8-7a48-416e-b87b-ec4bc6b60f27.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.55.27 PM.png_b7e7237b-0aac-4dfa-8ad8-94b5ed825d0b.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.33.47 PM.png_969853db-8eb4-4e74-81e6-e8dbae67af4c.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.24.35 PM.png_5cc2b87a-ffe4-4f88-81e3-71f3853da0cb.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.15.20 PM.png_a838d438-9e5e-4b21-86ad-7339b787c0e3.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.52.09 PM.png_eeec60af-c7c1-4730-be84-864f46d4a44f.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.18.57 PM.png_ba1eeb1e-a227-4125-b150-16adf314f768.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.16.41 PM.png_fadbb708-8890-4b7d-b8d0-808128980ed4.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.33.47 PM.png_46bba2b7-fc86-4b9b-8802-f8f0640db38d.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.16.18 PM.png_56388453-389c-451d-bf67-5ec94d7201c8.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.23.02 PM.png_765e7e4b-31b7-47ac-942a-4f119a45b615.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.54.08 PM.png_0d0ffaad-e6e3-4b6c-b286-bef4e735c6e1.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.19.46 PM.png_da95ebf9-280d-4655-84f6-0a286e6397af.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.46.52 PM.png_2d3b6f6f-d4c7-4e8b-9097-4071d60ed712.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.35.21 PM.png_7c1dfa93-46eb-43da-85b9-a32e307751d8.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.45.35 PM.png_1a9db602-cb3d-4a44-82a1-f51c1f3e58f9.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.47.20 PM.png_a975fae9-0886-44f5-81e9-895038a3d8c6.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.46.52 PM.png_4cb01190-0acd-4ac6-8b33-21cdcfe7a3b2.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.38.49 PM.png_fae9d4b7-2c4a-4a81-aba5-85f5052752b2.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.46.52 PM.png_67d69bb1-bc94-47e8-83ea-60b8ac29312f.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.24.35 PM.png_2dbdb182-1d15-4ca5-9087-c74583857286.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.19.37 PM.png_0f503eff-516b-42c6-914f-d099a7cfc5a8.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 3.17.25 PM.png_e848c6b8-7efd-4836-9e4a-99d8016a05cf.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.15.20 PM.png_3f00dee2-b351-4d5a-b455-acff339d6183.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.43.07 PM.png_b19eee33-82dd-428e-a9a2-7ae4eeeace24.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.47.13 PM.png_8c57f5f3-bc61-49e8-aec7-64c8fb22511b.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.42.58 PM.png_8d6c8c8a-45e1-4957-880c-358377f5a177.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.51.01 PM.png_0be94d80-e308-433a-b0ee-a9db57126268.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.25.16 PM.png_5772a8b7-9957-40e7-b7c7-5ce57b1105f0.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.44.59 PM.png_98ce3cbe-d6f8-4c74-9b99-93015bbb00bb.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.47.27 PM.png_e647952a-0eb2-4db0-97b9-99f38cc6fd01.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.43.54 PM.png_3fbc6296-047e-4fc7-8760-224f305ad68f.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.46.52 PM.png_e1dc7a28-0689-47e5-a2a2-61351a5ffa45.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.45.35 PM.png_25e1d72d-95c7-4887-9d55-a0262db6b2d2.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.18.57 PM.png_bdacd62b-6443-4049-a916-4c27198dbf11.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.43.07 PM.png_5d901c14-9829-4240-a703-78bfb4d2a94c.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.47.13 PM.png_cf7e8e0b-b890-4260-9a83-e121638f1a29.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.24.02 PM.png_cf258027-6265-493c-b3b8-4fc05ba8ee98.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.40.55 PM.png_1a4c25a9-92e4-4046-af25-8fc86a93bba4.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.19.46 PM.png_b9b4bf94-a7f5-452e-b11e-a5505fe20a64.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.52.44 PM.png_6dc24f64-b3ef-454e-b919-8d552dd18ca4.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.33.47 PM.png_e544d164-ab49-4cb8-b115-adaa4bda8750.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.16.18 PM.png_e9cb2369-b456-4ad3-90db-7f171d43cb79.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.15.50 PM.png_98edaa8f-220c-497c-909b-96217733dd75.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.23.51 PM.png_59169d9d-89ce-48df-81a1-bbb648556f1b.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.53.20 PM.png_f426bf6b-f8c9-4a26-a3b1-3dbbe002dbda.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.40.55 PM.png_66bef3b7-ab46-4ec1-9969-8cf5b7a408fd.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.52.22 PM.png_6dc8399c-0d4d-48d7-9459-5942cfd38107.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.34.18 PM.png_f38e882d-3d13-4437-89c8-09c8a362bd6f.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.52.22 PM.png_1cb764db-e06f-4021-9d1c-136df7962633.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.33.47 PM.png_e9371ed1-979d-46ca-8630-d946a7da9f63.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.16.18 PM.png_c6e33f92-9794-4d23-9002-4b5f3261f723.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.41.07 PM.png_25b34338-791d-41af-89a2-706af6f59e90.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.42.18 PM.png_c8fd9375-a1b2-4ee5-b1f4-1c7f57053d2f.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.42.58 PM.png_26001718-6fd8-4313-8eca-2f59dda63e0d.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.51.01 PM.png_dd1fc685-e717-4738-8f9d-a8c43f6b4bb7.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.33.47 PM.png_c165aed8-f9a6-45e4-945f-d29b7e736a73.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.42.18 PM.png_d56a9fea-2446-4d14-94a3-3735871db950.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.38.28 PM.png_13f7819a-aae3-478e-b4b2-da83b166d3c5.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.52.22 PM.png_f1871132-4329-4fd8-8f57-1b7681f0f246.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.19.46 PM.png_a6e83ec6-5666-401a-8204-4b0fe0f82998.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.47.35 PM.png_e6eef9bd-27be-417d-a1f6-b9f4c0e5ff49.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.41.32 PM.png_1a5651c8-a01b-479d-a567-288f187541b6.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.52.22 PM.png_b66a22c3-67f9-4039-a05f-4c06e76725aa.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.38.49 PM.png_925252f6-5e1b-4d2f-aaa6-c1568710dc83.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.47.35 PM.png_3f0ca69f-b882-4b21-bd8a-40b7dd7256be.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.35.21 PM.png_00f13d43-1011-49b4-905b-7d968d3d42c5.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.47.27 PM.png_e7f74555-a295-40f1-b52a-2163c34be29d.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.57.26 PM.png_c5c32f55-bc4c-44ca-b2a1-5a35e333585a.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.50.31 PM.png_3a828e63-a95c-4221-9cb0-dc55df82ccb2.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.56.34 PM.png_84307aa0-a670-494f-be4f-211967418a1f.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.57.05 PM.png_e348eabe-697c-444a-8c56-40d7818ece47.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.37.11 PM.png_712cc96a-6f68-4796-b65d-f56e95b31bfb.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.43.13 PM.png_91815c6d-3807-475d-a112-5d4dcc6702b1.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.19.15 PM.png_78db1e1f-d1e5-435f-a6df-2ff7aeb3c957.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.31.43 PM.png_e2248e91-27e1-4974-9243-090b76e6c69c.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.44.59 PM.png_ea45572d-aade-4824-8d59-211013bf7727.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.53.33 PM.png_4da6d96a-00a2-4a0a-8b4a-c130e3ae2720.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.38.04 PM.png_fc037283-b73a-4d04-80ca-0206574d95f9.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 3.00.17 PM.png_0e004b6d-9e77-4d50-81b1-9c67e2e24cba.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.25.16 PM.png_939cff87-e34d-4b94-b626-9511c28a117d.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.46.52 PM.png_1e83659c-b88f-4621-84ce-278c15f9e67b.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.47.20 PM.png_63b79412-d6f7-46c7-b7c2-09ff9058e39b.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.19.15 PM.png_5407f68e-c282-4567-bfbe-6d80d550ce94.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.42.25 PM.png_18479e9b-8b30-41b3-a068-431144ba89e5.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.31.59 PM.png_a5ef0107-7415-4baf-b5b5-a824ae6895b9.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.17.25 PM.png_af526e6c-6ac8-4632-8a51-3abf777234c6.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.51.01 PM.png_f5b9e454-28cc-4e6e-ab4a-25acd88b3952.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.47.35 PM.png_e9cb88ee-b068-4d18-8cd4-d24865f00034.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.38.04 PM.png_36a19511-c043-4f30-8092-124e24873277.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 3.17.25 PM.png_d106a5eb-30a8-48c0-92db-3e23cd4be859.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.47.13 PM.png_f4829fd3-67b5-4b7b-a599-c02eb3c95ea5.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.22.00 PM.png_6a1bd6f4-9b07-4dd3-b657-ac05fe0cd2ec.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.44.59 PM.png_6de90559-3204-4b0d-95c4-d7e956af4481.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.42.25 PM.png_c30af770-65af-4dcd-ba26-eff54297ded6.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.57.13 PM.png_1b41f097-d686-4dbd-9b50-20c337b51d4e.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.46.52 PM.png_37a2bb3a-29a2-43b0-948c-ff5cfff59ca8.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.18.57 PM.png_ed7dfef2-9f1c-4a81-a6c6-f9d7d75b5ca9.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.24.47 PM.png_7e4d02d2-f652-4415-8dc6-632b4f62d287.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.47.35 PM.png_396d4b38-3f02-4094-be2b-4a80d734f428.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.52.09 PM.png_ff751fd0-142f-42ee-a5ba-b5b743a92d70.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.19.15 PM.png_f4de2a3e-597d-41a7-a9ed-bc57a80c6e6b.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.16.18 PM.png_5f96412c-7270-44ea-b650-1179c765b578.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.40.48 PM.png_91a9cdf1-4633-40a9-bddc-5adb473b021f.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.52.30 PM.png_354f169c-aee6-4104-84fd-b041b6098184.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.45.35 PM.png_7f1f5fd7-dd93-4f89-b3ea-55e39f3aa52c.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.44.59 PM.png_63af76fc-5fbb-4bd7-82ae-cd18555487de.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.41.32 PM.png_5787cb3d-fa71-482d-9be9-73ae244d6a69.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.23.40 PM.png_9e3bc0fa-fefa-4d02-813e-d461f54a4d8e.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.34.18 PM.png_def3bb07-4bf2-401d-b8b7-2d7e8e4d4c7a.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.57.17 PM.png_ad814d0e-0e2b-4cc5-bb00-2291d2e461b2.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.52.00 PM.png_fef0e396-3c98-47cc-b332-6339c34d127f.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.22.00 PM.png_5f54c560-e6f2-4609-9992-99b593bf5a9f.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.34.18 PM.png_ae899239-dec7-4aba-b775-fb43749fec28.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.47.20 PM.png_2a7c7920-bec9-43d6-b4e2-f24497168e7a.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 3.17.25 PM.png_9adba9a2-d8fb-475c-92dc-f92a8536dcb3.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.15.50 PM.png_eb2441dd-529b-46f9-8df4-2624317855a7.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.59.52 PM.png_1c48e951-7d72-4d52-81f5-b78aa38e2f5e.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.59.52 PM.png_0eb0a8c1-344e-4d48-8143-28c07eb81ebc.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.38.28 PM.png_e6f3579f-600a-4977-a15d-636a7cc0e5e9.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.43.13 PM.png_102091bf-23aa-4cad-9cc4-1dbfc807100f.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.19.37 PM.png_1de347c2-0ac7-4201-b69e-02f6986a71be.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.24.35 PM.png_f3fe9a23-cf20-4b4a-8e90-1eb7d7c6f922.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.23.02 PM.png_fd50bec8-5946-4655-9c26-7d5a3a423d9e.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.52.00 PM.png_7dfa9391-8406-46c3-b0d8-64fb060f6d1f.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.35.21 PM.png_23660a19-e3dd-46dd-937c-7675a62184ad.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.40.55 PM.png_9031b09a-3f15-442f-8c62-0b19a24a6ad9.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.52.44 PM.png_23472920-c092-46d9-8a60-594737f9b037.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.54.58 PM.png_a7c8221b-db3b-428c-a237-e79517035d6b.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.16.18 PM.png_94b3c9ef-cb82-4518-94b5-1974aa9028ea.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.34.18 PM.png_c08f6372-0e37-45b5-ade5-35ac99336e4d.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.15.50 PM.png_0cfcc87f-11dd-466f-9c81-97f529383295.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.41.07 PM.png_b94eda84-66e6-4302-88b0-c1e30a8ae128.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.19.37 PM.png_2782e450-b6f2-4297-9379-5d2e37bb873a.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.23.40 PM.png_ba10dd7e-b132-430c-a0bc-e4ba3512a9e6.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.57.26 PM.png_6dbe8fb7-56b5-4623-8cc3-954c26eedaca.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.57.26 PM.png_3858a2bb-96af-495b-acbb-7d409e8897a0.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.40.55 PM.png_676b3703-70f2-4f47-8de6-664cca32248c.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.15.20 PM.png_7e3f756f-7eb9-431c-a62b-449d8d72c8c9.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.41.07 PM.png_6184e5ff-dfc5-477a-8942-24eb0806daf7.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.57.26 PM.png_c1c31d12-4261-4810-bbfc-d657fff23735.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.57.05 PM.png_cebf2864-3d2f-4fe7-9bea-76fce6a9911b.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.47.13 PM.png_7acd5c40-3a65-4de7-bf80-f89c4939d1e2.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.52.22 PM.png_fb7a2b87-46ce-46a7-b44e-e12071704f2b.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.59.38 PM.png_2e389822-5577-4b1a-87d8-314295209368.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.53.20 PM.png_ba630998-52f3-4abb-836d-c130a3788dc3.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.50.31 PM.png_d503e30f-9955-4fa3-937a-6a8a8603c427.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.16.41 PM.png_1079effa-21ed-43d9-8631-698280329eb1.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.53.20 PM.png_32c2f0fa-50a7-49af-b192-0fd6034e4c79.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.56.34 PM.png_46976993-1f29-440a-b418-7832df188ab3.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.40.28 PM.png_7f5a6003-a420-475c-8263-833a4579209a.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.57.26 PM.png_50864211-f385-42b5-86aa-b525fd9b7734.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.18.57 PM.png_ff4f6924-acfe-4208-ab89-63e7ce9ae15a.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.43.07 PM.png_d39025c8-4b65-4b32-bb1d-8a8663c6621a.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 3.00.17 PM.png_7c78acd0-2f98-4609-8f10-184eb0d32ca3.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.23.51 PM.png_636f6961-12b8-42cf-a5d3-8ba546075926.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.52.30 PM.png_5267b190-84c6-4483-9685-a572d73fd50f.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.42.18 PM.png_6263a0e8-5df4-44a0-ae2b-019c8865fc4f.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.52.30 PM.png_717ed90f-821d-4e22-aeef-ad9a65c18957.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.19.46 PM.png_db6d7327-cccf-4efa-a41d-f169cdb03728.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.52.44 PM.png_6eec8d56-89e3-46b9-b11d-98ae8b41b3e4.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.43.26 PM.png_1b149343-f734-4608-b335-464e15b9ed61.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.45.35 PM.png_a941eee0-5c7f-47a5-92fc-d21154088cc2.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.52.30 PM.png_d2e55c5a-a55f-44c1-b2f3-650235ac8cce.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.47.13 PM.png_d6ba4cc7-f9bd-411b-8646-94e214918d4d.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.51.01 PM.png_81e8d5c3-dfc0-4daf-9019-1acbf45da802.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.42.25 PM.png_1677563c-b61d-46e6-8929-e895bc6a386f.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.37.11 PM.png_c3d5f3b8-c6f1-43dd-8f77-2f7bff89b400.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.50.31 PM.png_5d6ff396-da3c-496b-8ee3-79700e2a77b8.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.41.07 PM.png_6c76cbb7-e039-4bc8-b6e2-67ae303283f3.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.57.13 PM.png_82e4646d-3d37-40e0-87a2-5363b72f177a.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.59.52 PM.png_8a9a433d-886d-49b9-bec9-8c8c96143720.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.43.13 PM.png_a65b6d2e-59b8-4206-b751-b3d397496fe4.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.44.59 PM.png_39a4c93b-dffb-4a78-aaed-48296ada07a0.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.47.35 PM.png_2ee9e5a8-d3a2-471a-9f14-818ecead5471.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.22.00 PM.png_11ab7682-5d36-4ed1-9c27-cbafe814b8ee.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.15.20 PM.png_12c6c9cf-e061-41b1-8b31-adc605f67a20.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.47.27 PM.png_3d73d8ba-4b1d-4f0d-8dca-634b47239c38.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.33.47 PM.png_bd87a233-9098-47b3-87e8-86de29581cdf.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.42.25 PM.png_56f3b5fb-7c55-460f-b9a5-0e0e7794e799.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.38.04 PM.png_0417390e-be6d-4696-96a5-444d8ae2bf55.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.40.28 PM.png_4b082011-23c1-4c5c-8d51-f59c4e3090ee.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.35.21 PM.png_cde9252f-7173-4dc1-bae6-1a37e6bf953a.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.57.13 PM.png_c06180cb-bd27-4cd1-b261-fdaf86223a58.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.47.13 PM.png_9d7b86ec-4794-472b-a4c4-9a74e9e4c8c6.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.17.25 PM.png_4e77a720-e393-427c-ba00-d53a46b9710d.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.56.34 PM.png_90bf6760-aee9-4966-aa9a-7fbd7af6fd8b.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.43.13 PM.png_3217a677-a129-4af2-9d28-07044f23e970.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.47.20 PM.png_1910ad61-b4f5-4393-aa40-5eb0bbb88b6c.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.54.08 PM.png_6f7a9479-e1e0-41f1-8879-ddf244ce6ef1.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.59.52 PM.png_2d42f113-5e1e-4e2e-9d52-2f8a25fec12b.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.53.33 PM.png_557d97a1-2f56-40cb-835a-c617fd3c3a20.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.16.41 PM.png_8bec88e0-0f05-49ad-937b-9977bde0611b.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.37.43 PM.png_061edf42-58e1-43b8-9739-871f16dc2d74.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.23.02 PM.png_8e4d9b24-90b4-48ed-8f36-2f23494fa94e.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.42.18 PM.png_fa5db8ea-0e45-4520-8fe9-dc13d8d92de9.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.16.18 PM.png_b5b836d5-fc49-44c7-b336-cea21e2f20b0.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.50.31 PM.png_cb6f57ca-bcfe-462f-8507-0f6a61affe6e.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.23.24 PM.png_c80dd5d7-7f38-4d0a-b865-b9e01a9bfd2f.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.24.47 PM.png_0043a42a-30ea-4631-9749-e981c1db54b3.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.16.18 PM.png_ac905235-4c50-44ff-b5f6-6c733c727205.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.19.37 PM.png_7adabcd1-7128-44a1-b0f7-892b084de3bf.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.15.20 PM.png_2db8e10e-b9f1-4c7c-9248-74b8dfe8b8d2.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.18.57 PM.png_30ed956f-7dee-4f77-ad0b-1dd2757021ed.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.38.49 PM.png_9dff3e8c-bff8-4db0-aa33-e7c6e9f82f05.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.34.18 PM.png_50abb7a0-efa2-4239-96bd-db79d217e4b5.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.57.05 PM.png_e057ad91-59be-402e-8e6c-44f126e3069a.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.43.13 PM.png_798da47f-02d1-461f-8a1c-d9ddb8a3bb80.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.38.04 PM.png_a21996d3-952a-4446-8494-fe67a5182bae.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.15.50 PM.png_711c45cc-9dd7-4b64-93eb-2e698c4df2d1.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.56.34 PM.png_8e90cf3e-b348-4e1b-8884-2f38ec262e6c.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.37.43 PM.png_7d119aaa-3d86-4dd0-9a8c-7703514bf20d.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.18.13 PM.png_68625dc8-1a56-4209-981e-fa83c584d530.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.52.44 PM.png_5ce3f8ab-e58e-4692-ae3c-91e7ee4914f2.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.33.47 PM.png_b45fc360-09b1-45ab-bcb2-a561f1a51963.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 3.17.25 PM.png_356bba71-cd6e-4b91-836a-76828f67c57d.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.24.35 PM.png_b8bf2430-35ac-4268-be8a-7a2e47d36d03.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.43.26 PM.png_2be90c65-091a-451b-a115-3b01ea18dd33.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.57.13 PM.png_29c1937a-0b3c-499f-ae68-a380e5f85d73.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.53.33 PM.png_6101980d-dc60-4b1b-9ef8-d3b7249039ce.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.58.57 PM.png_ec0c7bb6-21c7-4872-9c1a-e85d3b3bd594.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.44.59 PM.png_559aede7-4fbd-49fe-b5d5-acef4c39ff08.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.22.00 PM.png_f1f6d403-b2ae-4151-a37e-c0dde2e8fc54.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.43.26 PM.png_799520fb-bccc-43cb-b989-77e91885ad1f.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.45.35 PM.png_95048e4a-24c1-4168-8838-4728e33e4a0f.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.53.20 PM.png_7e305ff2-76ba-4dfc-8ab7-7a27827ecd6e.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.18.57 PM.png_201f763f-09e9-4c6b-b655-0b1c5a5f1f2a.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.58.57 PM.png_ae55d124-3d5e-407c-ae15-eba14f21ed92.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 3.17.25 PM.png_700f24e5-7fe9-490a-bfd2-a16ea1c9ed46.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.56.34 PM.png_993ed750-e1e0-456b-87b7-3e903e60032a.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.18.13 PM.png_5a7df201-6ee5-42a0-b314-dd5623aaf8fb.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.37.43 PM.png_1729cbf0-6e91-4f5b-b440-50c4e5e346dc.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.23.51 PM.png_85189d29-8c42-4a01-bb82-c03080471871.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.19.46 PM.png_54ce3807-5e59-4c89-bec1-abf7270970e3.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.58.57 PM.png_4f21d355-7d23-4cd7-bd82-ababfabe1777.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.56.34 PM.png_d96dbfdb-c361-45c0-a545-e7e805655823.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.24.47 PM.png_9583374d-5a53-47c9-b8e9-d992ab427fe9.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.23.24 PM.png_171ca47c-58f0-4683-a0df-0bd7e9d54225.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.43.26 PM.png_43e32c86-74f0-4eed-97aa-d6b911a0c365.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.47.27 PM.png_b7f0bd0c-314f-4f4b-9fe3-5a8dc1409405.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.24.02 PM.png_8d98e2c3-5853-4107-ba9c-afe545962262.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.56.34 PM.png_060e2244-c031-40b8-bf65-c619a854c178.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.35.10 PM.png_475d1956-0f53-4d7a-a4f9-471a5459bf87.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.53.33 PM.png_8c73739a-a7eb-48e5-af39-c446569f812c.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.22.00 PM.png_34f2ceff-09cd-4b2e-82fb-2a67a68cdf1f.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.54.08 PM.png_5635a404-fcb7-4060-a426-c727b53f6634.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.38.04 PM.png_732ffb60-4c98-47ac-9d0c-8880c8ba3e57.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.44.51 PM.png_5396fe01-e4f5-472f-b33b-fcff0ad81994.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.34.18 PM.png_27479dc5-5933-48fd-92ef-da30a78cbfaf.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.38.28 PM.png_52cb7ae4-ebac-4630-8b87-5e6fe7e79a9d.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.33.47 PM.png_f277c690-4d78-4966-8e61-6ec5f45cc170.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.47.27 PM.png_c019940c-a2bc-49c1-b353-61646b3f36c6.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.52.22 PM.png_29bb00cd-8243-4c17-9d9b-a8ea905887e8.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.38.04 PM.png_04daa696-d99f-44bd-b81b-af6ed1f31dc7.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.40.55 PM.png_78546e2b-03c9-497f-8009-8f28499327e5.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.33.47 PM.png_ec643ee1-d2a9-4c9e-8dac-d5f6c651cc4d.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 3.00.17 PM.png_31fb27e3-47bc-4475-84ec-eb097647876d.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.46.52 PM.png_7623b3d4-a8b0-44c9-8429-f41faff092cf.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.24.02 PM.png_df0c2c9f-2525-4e01-a7cf-f0668340debb.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.35.21 PM.png_d53de589-4206-4795-b0cc-1866664da11b.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.24.02 PM.png_9c8d07ef-34cf-4e16-8739-9db88510f99a.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.25.16 PM.png_bff095a3-c1ff-417f-ba1c-628e480316c2.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.47.27 PM.png_b7865c67-e11d-4f58-9beb-a383bcffc85c.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.40.28 PM.png_72bcd3c5-2f55-4115-9c19-a7f55e0c6e47.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.40.48 PM.png_839537da-77cd-417e-8f53-a9b3ff77842f.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.40.48 PM.png_a79b4bf9-2717-4a33-905a-9a409ad2901d.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.17.15 PM.png_e2e0ef00-03b0-4c0e-97db-713802ba8f1f.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.23.24 PM.png_6a349116-a62a-4d87-9e63-d06ae086c7a2.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.25.16 PM.png_15fe6a5d-3f35-4bcb-9d2c-191058924fcf.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.52.09 PM.png_12315fc8-5bae-4153-9ce4-5bf896821772.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.34.18 PM.png_67fbe5d9-9067-454a-9e9d-7d3d1459f2f9.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.15.20 PM.png_42470045-7fd6-4c66-a975-9d207247ae1f.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.43.54 PM.png_02998dbe-7925-45c6-a11b-0def96b74aca.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.52.00 PM.png_35955246-ab21-443f-860d-e9f1ea3fb047.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.57.05 PM.png_0f4cf1c0-43a5-4113-80b2-91f1b983bb3e.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.57.05 PM.png_d62e8899-80f9-4a86-9264-ea2f9de93218.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.18.13 PM.png_1e910b33-cc3a-4d3f-9323-40a048a074d9.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.52.00 PM.png_75bb95d8-54a1-4d5c-b246-308af3f64b9e.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.24.47 PM.png_6abb3bf5-5af6-494e-8aa3-569d41da2032.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.42.25 PM.png_441fd5c7-9464-4a1f-a9a0-9e4781877b11.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.31.43 PM.png_daa9e0a3-1d20-4a39-b92a-b0d787a1517e.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.35.21 PM.png_1c0616a7-0835-4185-af2d-66e3f7b1fa15.png
# Found file: rotten apple_original_Screen Shot 2018-06-07 at 2.35.10 PM.png_a331072e-9817-489c-8fc2-01264df10b45.png
# ...
# Found file: rotten orange_original_Screen Shot 2018-06-12 at 11.36.24 PM.png_c7570b30-9f1f-4549-999a-a0e64f316a70.png
# Found file: rotten orange_original_Screen Shot 2018-06-12 at 11.42.05 PM.png_23ed4198-cfb5-43d7-b13c-a8f1f989ac02.png
# Found file: rotten orange_original_Screen Shot 2018-06-12 at 11.41.04 PM.png_94538ada-1f86-4f79-8320-dd1f5d9f49cc.png
# Found file: rotten orange_original_Screen Shot 2018-06-12 at 11.37.31 PM.png_79d752a8-df96-4bc5-aa6d-b6a1e5f1918b.png
# Found file: rotten orange_original_Screen Shot 2018-06-12 at 11.23.19 PM.png_9f46ddd5-1ef1-4091-adda-331ef8f1dbf6.png
# Found file: rotten orange_original_Screen Shot 2018-06-12 at 11.37.31 PM.png_2ad3a096-278c-4fe0-a38b-9c2f6016ecd6.png
# Found file: rotten orange_original_Screen Shot 2018-06-12 at 11.29.14 PM.png_69df9366-3adf-47df-aa83-66a571653792.png
# Found file: rotten orange_original_Screen Shot 2018-06-12 at 11.40.42 PM.png_c552e038-e335-4e20-a4f3-301519c89ae5.png
# Found file: rotten orange_original_Screen Shot 2018-06-12 at 11.40.36 PM.png_dddf26aa-5039-45fc-a402-6bc79907f6dc.png
# Found file: rotten orange_original_Screen Shot 2018-06-12 at 11.29.10 PM.png_82ad7cfa-bddc-495a-8861-e4772146c8de.png
# Found file: rotten orange_original_Screen Shot 2018-06-12 at 11.41.52 PM.png_14422e3b-b5a9-4541-934c-1a7bad13eb19.png
# Found file: rotten orange_original_Screen Shot 2018-06-12 at 11.42.45 PM.png_e7706b5c-e3aa-495e-9d57-930ec6e10733.png
# Found file: rotten orange_original_Screen Shot 2018-06-12 at 11.35.59 PM.png_b5126796-8311-483f-a6f1-f440d1b676b4.png
# Found file: rotten orange_original_Screen Shot 2018-06-12 at 11.37.45 PM.png_f6a24608-e574-4cef-b017-bb93b6584eac.png
# Found file: Screen Shot 2018-06-12 at 11.18.28 PM_saturation_adjusted_0.png
# Found file: Screen Shot 2018-06-12 at 11.18.41 PM_saturation_adjusted_1.png
# Found file: Screen Shot 2018-06-12 at 11.19.08 PM_saturation_adjusted_2.png
# Found file: Screen Shot 2018-06-12 at 11.19.16 PM_saturation_adjusted_3.png
# Found file: Screen Shot 2018-06-12 at 11.19.22 PM_saturation_adjusted_4.png
# Found file: Screen Shot 2018-06-12 at 11.20.18 PM_saturation_adjusted_5.png
# Found file: Screen Shot 2018-06-12 at 11.20.40 PM_saturation_adjusted_6.png
# Found file: Screen Shot 2018-06-12 at 11.20.52 PM_saturation_adjusted_7.png
# Found file: Screen Shot 2018-06-12 at 11.21.10 PM_saturation_adjusted_8.png
# Found file: Screen Shot 2018-06-12 at 11.22.41 PM_saturation_adjusted_9.png
# Found file: Screen Shot 2018-06-12 at 11.22.47 PM_saturation_adjusted_10.png
# Found file: Screen Shot 2018-06-12 at 11.23.13 PM_saturation_adjusted_11.png
# Found file: Screen Shot 2018-06-12 at 11.23.19 PM_saturation_adjusted_12.png
# Found file: Screen Shot 2018-06-12 at 11.23.24 PM_saturation_adjusted_13.png
# Found file: Screen Shot 2018-06-12 at 11.23.29 PM_saturation_adjusted_14.png
# Found file: Screen Shot 2018-06-12 at 11.23.40 PM_saturation_adjusted_15.png
# Found file: Screen Shot 2018-06-12 at 11.23.46 PM_saturation_adjusted_16.png
# Found file: Screen Shot 2018-06-12 at 11.23.54 PM_saturation_adjusted_17.png
# Found file: Screen Shot 2018-06-12 at 11.24.04 PM_saturation_adjusted_18.png
# Found file: Screen Shot 2018-06-12 at 11.25.11 PM_saturation_adjusted_19.png
# Found file: Screen Shot 2018-06-12 at 11.25.38 PM_saturation_adjusted_20.png
# Found file: Screen Shot 2018-06-12 at 11.27.52 PM_saturation_adjusted_21.png
# Found file: Screen Shot 2018-06-12 at 11.27.55 PM_saturation_adjusted_22.png
# Found file: Screen Shot 2018-06-12 at 11.28.00 PM_saturation_adjusted_23.png
# Found file: Screen Shot 2018-06-12 at 11.28.04 PM_saturation_adjusted_24.png
# Found file: Screen Shot 2018-06-12 at 11.28.08 PM_saturation_adjusted_25.png
# Found file: Screen Shot 2018-06-12 at 11.29.10 PM_saturation_adjusted_26.png
# Found file: Screen Shot 2018-06-12 at 11.29.14 PM_saturation_adjusted_27.png
# Found file: Screen Shot 2018-06-12 at 11.29.21 PM_saturation_adjusted_28.png
# Found file: Screen Shot 2018-06-12 at 11.29.26 PM_saturation_adjusted_29.png
# Found file: Screen Shot 2018-06-12 at 11.29.36 PM_saturation_adjusted_30.png
# Found file: Screen Shot 2018-06-12 at 11.29.51 PM_saturation_adjusted_31.png
# Found file: Screen Shot 2018-06-12 at 11.30.41 PM_saturation_adjusted_32.png
# Found file: Screen Shot 2018-06-12 at 11.32.41 PM_saturation_adjusted_33.png
# Found file: Screen Shot 2018-06-12 at 11.32.50 PM_saturation_adjusted_34.png
# Found file: Screen Shot 2018-06-12 at 11.33.16 PM_saturation_adjusted_35.png
# Found file: Screen Shot 2018-06-12 at 11.33.23 PM_saturation_adjusted_36.png
# Found file: Screen Shot 2018-06-12 at 11.33.43 PM_saturation_adjusted_37.png
# Found file: Screen Shot 2018-06-12 at 11.35.51 PM_saturation_adjusted_38.png
# Found file: Screen Shot 2018-06-12 at 11.35.55 PM_saturation_adjusted_39.png
# Found file: Screen Shot 2018-06-12 at 11.35.59 PM_saturation_adjusted_40.png
# Found file: Screen Shot 2018-06-12 at 11.36.14 PM_saturation_adjusted_41.png
# Found file: Screen Shot 2018-06-12 at 11.36.19 PM_saturation_adjusted_42.png
# Found file: Screen Shot 2018-06-12 at 11.36.24 PM_saturation_adjusted_43.png
# Found file: Screen Shot 2018-06-12 at 11.36.31 PM_saturation_adjusted_44.png
# Found file: Screen Shot 2018-06-12 at 11.36.35 PM_saturation_adjusted_45.png
# Found file: Screen Shot 2018-06-12 at 11.36.48 PM_saturation_adjusted_46.png
# Found file: Screen Shot 2018-06-12 at 11.36.53 PM_saturation_adjusted_47.png
# Found file: Screen Shot 2018-06-12 at 11.37.07 PM_saturation_adjusted_48.png
# Found file: Screen Shot 2018-06-12 at 11.37.13 PM_saturation_adjusted_49.png
# Found file: Screen Shot 2018-06-12 at 11.37.19 PM_saturation_adjusted_50.png
# Found file: Screen Shot 2018-06-12 at 11.37.25 PM_saturation_adjusted_51.png
# Found file: Screen Shot 2018-06-12 at 11.37.31 PM_saturation_adjusted_52.png
# Found file: Screen Shot 2018-06-12 at 11.37.36 PM_saturation_adjusted_53.png
# Found file: Screen Shot 2018-06-12 at 11.37.41 PM_saturation_adjusted_54.png
# Found file: Screen Shot 2018-06-12 at 11.37.45 PM_saturation_adjusted_55.png
# Found file: Screen Shot 2018-06-12 at 11.37.58 PM_saturation_adjusted_56.png
# Found file: Screen Shot 2018-06-12 at 11.38.19 PM_saturation_adjusted_57.png
# Found file: Screen Shot 2018-06-12 at 11.38.46 PM_saturation_adjusted_58.png
# Found file: Screen Shot 2018-06-12 at 11.38.52 PM_saturation_adjusted_59.png
# Found file: Screen Shot 2018-06-12 at 11.39.02 PM_saturation_adjusted_60.png
# Found file: Screen Shot 2018-06-12 at 11.39.29 PM_saturation_adjusted_61.png
# Found file: Screen Shot 2018-06-12 at 11.40.11 PM_saturation_adjusted_62.png
# Found file: Screen Shot 2018-06-12 at 11.40.36 PM_saturation_adjusted_63.png
# Found file: Screen Shot 2018-06-12 at 11.40.42 PM_saturation_adjusted_64.png
# Found file: Screen Shot 2018-06-12 at 11.41.04 PM_saturation_adjusted_65.png
# Found file: Screen Shot 2018-06-12 at 11.41.08 PM_saturation_adjusted_66.png
# Found file: Screen Shot 2018-06-12 at 11.41.26 PM_saturation_adjusted_67.png
# Found file: Screen Shot 2018-06-12 at 11.41.52 PM_saturation_adjusted_68.png
# Found file: Screen Shot 2018-06-12 at 11.42.00 PM_saturation_adjusted_69.png
# Found file: Screen Shot 2018-06-12 at 11.42.05 PM_saturation_adjusted_70.png
# Found file: Screen Shot 2018-06-12 at 11.42.45 PM_saturation_adjusted_71.png
# Found file: Screen Shot 2018-06-12 at 11.42.52 PM_saturation_adjusted_72.png
# Found file: Screen Shot 2018-06-12 at 11.42.56 PM_saturation_adjusted_73.png
# Found file: Screen Shot 2018-06-12 at 11.43.03 PM_saturation_adjusted_74.png
# Found file: Screen Shot 2018-06-12 at 11.18.28 PM_saturation_adjusted_75.png
# Found file: Screen Shot 2018-06-12 at 11.18.41 PM_saturation_adjusted_76.png
# Found file: Screen Shot 2018-06-12 at 11.19.08 PM_saturation_adjusted_77.png
# Found file: Screen Shot 2018-06-12 at 11.19.16 PM_saturation_adjusted_78.png
# Found file: Screen Shot 2018-06-12 at 11.19.22 PM_saturation_adjusted_79.png
# Found file: Screen Shot 2018-06-12 at 11.20.18 PM_saturation_adjusted_80.png
# Found file: Screen Shot 2018-06-12 at 11.20.40 PM_saturation_adjusted_81.png
# Found file: Screen Shot 2018-06-12 at 11.20.52 PM_saturation_adjusted_82.png
# Found file: Screen Shot 2018-06-12 at 11.21.10 PM_saturation_adjusted_83.png
# Found file: Screen Shot 2018-06-12 at 11.22.41 PM_saturation_adjusted_84.png
# Found file: Screen Shot 2018-06-12 at 11.22.47 PM_saturation_adjusted_85.png
# Found file: Screen Shot 2018-06-12 at 11.23.13 PM_saturation_adjusted_86.png
# Found file: Screen Shot 2018-06-12 at 11.23.19 PM_saturation_adjusted_87.png
# Found file: Screen Shot 2018-06-12 at 11.23.24 PM_saturation_adjusted_88.png
# Found file: Screen Shot 2018-06-12 at 11.23.29 PM_saturation_adjusted_89.png
# Found file: Screen Shot 2018-06-12 at 11.23.40 PM_saturation_adjusted_90.png
# Found file: Screen Shot 2018-06-12 at 11.23.46 PM_saturation_adjusted_91.png
# Found file: Screen Shot 2018-06-12 at 11.23.54 PM_saturation_adjusted_92.png
# Found file: Screen Shot 2018-06-12 at 11.24.04 PM_saturation_adjusted_93.png
# Found file: Screen Shot 2018-06-12 at 11.25.11 PM_saturation_adjusted_94.png
# Found file: Screen Shot 2018-06-12 at 11.25.38 PM_saturation_adjusted_95.png
# Found file: Screen Shot 2018-06-12 at 11.27.52 PM_saturation_adjusted_96.png
# Found file: Screen Shot 2018-06-12 at 11.27.55 PM_saturation_adjusted_97.png
# Found file: Screen Shot 2018-06-12 at 11.28.00 PM_saturation_adjusted_98.png
# Found file: Screen Shot 2018-06-12 at 11.28.04 PM_saturation_adjusted_99.png
# Found file: Screen Shot 2018-06-12 at 11.28.08 PM_saturation_adjusted_100.png
# Found file: Screen Shot 2018-06-12 at 11.29.10 PM_saturation_adjusted_101.png
# Found file: Screen Shot 2018-06-12 at 11.29.14 PM_saturation_adjusted_102.png
# Found file: Screen Shot 2018-06-12 at 11.29.21 PM_saturation_adjusted_103.png
# Found file: Screen Shot 2018-06-12 at 11.29.26 PM_saturation_adjusted_104.png
# Found file: Screen Shot 2018-06-12 at 11.29.36 PM_saturation_adjusted_105.png
# Found file: Screen Shot 2018-06-12 at 11.29.51 PM_saturation_adjusted_106.png
# Found file: Screen Shot 2018-06-12 at 11.30.41 PM_saturation_adjusted_107.png
# Found file: Screen Shot 2018-06-12 at 11.32.41 PM_saturation_adjusted_108.png
# Found file: Screen Shot 2018-06-12 at 11.32.50 PM_saturation_adjusted_109.png
# Found file: Screen Shot 2018-06-12 at 11.33.16 PM_saturation_adjusted_110.png
# Found file: Screen Shot 2018-06-12 at 11.33.23 PM_saturation_adjusted_111.png
# Found file: Screen Shot 2018-06-12 at 11.33.43 PM_saturation_adjusted_112.png
# Found file: Screen Shot 2018-06-12 at 11.35.51 PM_saturation_adjusted_113.png
# Found file: Screen Shot 2018-06-12 at 11.35.55 PM_saturation_adjusted_114.png
# Found file: Screen Shot 2018-06-12 at 11.35.59 PM_saturation_adjusted_115.png
# Found file: Screen Shot 2018-06-12 at 11.36.14 PM_saturation_adjusted_116.png
# Found file: Screen Shot 2018-06-12 at 11.36.19 PM_saturation_adjusted_117.png
# Found file: Screen Shot 2018-06-12 at 11.36.24 PM_saturation_adjusted_118.png
# Found file: Screen Shot 2018-06-12 at 11.36.31 PM_saturation_adjusted_119.png
# Found file: Screen Shot 2018-06-12 at 11.36.35 PM_saturation_adjusted_120.png
# Found file: Screen Shot 2018-06-12 at 11.36.48 PM_saturation_adjusted_121.png
# Found file: Screen Shot 2018-06-12 at 11.36.53 PM_saturation_adjusted_122.png
# Found file: Screen Shot 2018-06-12 at 11.37.07 PM_saturation_adjusted_123.png
# Found file: Screen Shot 2018-06-12 at 11.37.13 PM_saturation_adjusted_124.png
# Found file: Screen Shot 2018-06-12 at 11.37.19 PM_saturation_adjusted_125.png
# Found file: Screen Shot 2018-06-12 at 11.37.25 PM_saturation_adjusted_126.png
# Found file: Screen Shot 2018-06-12 at 11.37.31 PM_saturation_adjusted_127.png
# Found file: Screen Shot 2018-06-12 at 11.37.36 PM_saturation_adjusted_128.png
# Found file: Screen Shot 2018-06-12 at 11.37.41 PM_saturation_adjusted_129.png
# Found file: Screen Shot 2018-06-12 at 11.37.45 PM_saturation_adjusted_130.png
# Found file: Screen Shot 2018-06-12 at 11.37.58 PM_saturation_adjusted_131.png
# Found file: Screen Shot 2018-06-12 at 11.38.19 PM_saturation_adjusted_132.png
# Found file: Screen Shot 2018-06-12 at 11.38.46 PM_saturation_adjusted_133.png
# Found file: Screen Shot 2018-06-12 at 11.38.52 PM_saturation_adjusted_134.png
# Found file: Screen Shot 2018-06-12 at 11.39.02 PM_saturation_adjusted_135.png
# Found file: Screen Shot 2018-06-12 at 11.39.29 PM_saturation_adjusted_136.png
# Found file: Screen Shot 2018-06-12 at 11.40.11 PM_saturation_adjusted_137.png
# Found file: Screen Shot 2018-06-12 at 11.40.36 PM_saturation_adjusted_138.png
# Found file: Screen Shot 2018-06-12 at 11.40.42 PM_saturation_adjusted_139.png
# Found file: Screen Shot 2018-06-12 at 11.41.04 PM_saturation_adjusted_140.png
# Found file: Screen Shot 2018-06-12 at 11.41.08 PM_saturation_adjusted_141.png
# Found file: Screen Shot 2018-06-12 at 11.41.26 PM_saturation_adjusted_142.png
# Found file: Screen Shot 2018-06-12 at 11.41.52 PM_saturation_adjusted_143.png
# Found file: Screen Shot 2018-06-12 at 11.42.00 PM_saturation_adjusted_144.png
# Found file: Screen Shot 2018-06-12 at 11.42.05 PM_saturation_adjusted_145.png
# Found file: Screen Shot 2018-06-12 at 11.42.45 PM_saturation_adjusted_146.png
# Found file: Screen Shot 2018-06-12 at 11.42.52 PM_saturation_adjusted_147.png
# Found file: Screen Shot 2018-06-12 at 11.42.56 PM_saturation_adjusted_148.png
# Found file: Screen Shot 2018-06-12 at 11.43.03 PM_saturation_adjusted_149.png
# Found file: Screen Shot 2018-06-12 at 11.18.28 PM_saturation_adjusted_150.png
# Found file: Screen Shot 2018-06-12 at 11.18.41 PM_saturation_adjusted_151.png
# Found file: Screen Shot 2018-06-12 at 11.19.08 PM_saturation_adjusted_152.png
# Found file: Screen Shot 2018-06-12 at 11.19.16 PM_saturation_adjusted_153.png
# Found file: Screen Shot 2018-06-12 at 11.19.22 PM_saturation_adjusted_154.png
# Found file: Screen Shot 2018-06-12 at 11.20.18 PM_saturation_adjusted_155.png
# Found file: Screen Shot 2018-06-12 at 11.20.40 PM_saturation_adjusted_156.png
# Found file: Screen Shot 2018-06-12 at 11.20.52 PM_saturation_adjusted_157.png
# Found file: Screen Shot 2018-06-12 at 11.21.10 PM_saturation_adjusted_158.png
# Found file: Screen Shot 2018-06-12 at 11.22.41 PM_saturation_adjusted_159.png
# Found file: Screen Shot 2018-06-12 at 11.22.47 PM_saturation_adjusted_160.png
# Found file: Screen Shot 2018-06-12 at 11.23.13 PM_saturation_adjusted_161.png
# Found file: Screen Shot 2018-06-12 at 11.23.19 PM_saturation_adjusted_162.png
# Found file: Screen Shot 2018-06-12 at 11.23.24 PM_saturation_adjusted_163.png
# Found file: Screen Shot 2018-06-12 at 11.23.29 PM_saturation_adjusted_164.png
# Found file: Screen Shot 2018-06-12 at 11.23.40 PM_saturation_adjusted_165.png
# Found file: Screen Shot 2018-06-12 at 11.23.46 PM_saturation_adjusted_166.png
# Found file: Screen Shot 2018-06-12 at 11.23.54 PM_saturation_adjusted_167.png
# Found file: Screen Shot 2018-06-12 at 11.24.04 PM_saturation_adjusted_168.png
# Found file: Screen Shot 2018-06-12 at 11.25.11 PM_saturation_adjusted_169.png
# Found file: Screen Shot 2018-06-12 at 11.25.38 PM_saturation_adjusted_170.png
# Found file: Screen Shot 2018-06-12 at 11.27.52 PM_saturation_adjusted_171.png
# Found file: Screen Shot 2018-06-12 at 11.27.55 PM_saturation_adjusted_172.png
# Found file: Screen Shot 2018-06-12 at 11.28.00 PM_saturation_adjusted_173.png
# Found file: Screen Shot 2018-06-12 at 11.28.04 PM_saturation_adjusted_174.png
# Found file: Screen Shot 2018-06-12 at 11.28.08 PM_saturation_adjusted_175.png
# Found file: Screen Shot 2018-06-12 at 11.29.10 PM_saturation_adjusted_176.png
# Found file: Screen Shot 2018-06-12 at 11.29.14 PM_saturation_adjusted_177.png
# Found file: Screen Shot 2018-06-12 at 11.29.21 PM_saturation_adjusted_178.png
# Found file: Screen Shot 2018-06-12 at 11.29.26 PM_saturation_adjusted_179.png
# Found file: Screen Shot 2018-06-12 at 11.29.36 PM_saturation_adjusted_180.png
# Found file: Screen Shot 2018-06-12 at 11.29.51 PM_saturation_adjusted_181.png
# Found file: Screen Shot 2018-06-12 at 11.30.41 PM_saturation_adjusted_182.png
# Found file: Screen Shot 2018-06-12 at 11.32.41 PM_saturation_adjusted_183.png
# Found file: Screen Shot 2018-06-12 at 11.32.50 PM_saturation_adjusted_184.png

# %% [markdown]
# ## **2.2 모델 성능 평가**

# %%
from tensorflow.keras.models import load_model

# 최상의 모델 로드
best_model_path = '/content/drive/MyDrive/fruit_image_dataset/dataset/efficientnet_b0_best_model.keras'
model = load_model(best_model_path)

# 테스트 데이터셋을 사용하여 모델 성능 평가
test_loss, test_accuracy = model.evaluate(test_generator)
print(f'Test Accuracy: {test_accuracy:.4f}')
print(f'Test Loss: {test_loss:.4f}')
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 218s 19s/step - accuracy: 0.2495 - loss: 19871.9648
# Test Accuracy: 0.2500
# Test Loss: 19534.3105

# %% [markdown]
# # **3. Validation 데이터 변경**

# %% [markdown]
# # **4. 하이퍼 파라미터 튜닝**

# %% [markdown]
# ## **4.1 모델 학습**
# ---
# **개선한 사항**
#
# * **Dropout 레이어** 추가 : Dropout(0.5)을 추가하여, 학습 시 뉴런의 50%를 무작위로 비활성화하여 과적합을 방지
# * **정규화(Regularization)** : Dense 레이어에서 kernel_regularizer=l2(0.001)를 사용하여 L2 정규화를 적용. ➡ **0.001로 설정**

# %%
# GPU가 사용 가능한지 확인
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# 이미지를 리사이징하기 전에 패딩을 추가
def pad_to_square(img):
    old_size = tf.shape(img)[:2]
    desired_size = tf.reduce_max(old_size)
    delta_w = desired_size - old_size[1]
    delta_h = desired_size - old_size[0]
    top = delta_h // 2
    bottom = delta_h - top
    left = delta_w // 2
    right = delta_w - left
    new_img = tf.image.pad_to_bounding_box(img, top, left, desired_size, desired_size)
    new_img = tf.image.resize(new_img, (224, 224))  # 다시 224x224로 리사이즈
    return new_img

# 데이터 경로 설정
train_dir = '/content/drive/MyDrive/fruit_image_dataset/dataset/train'
val_dir = '/content/drive/MyDrive/fruit_image_dataset/dataset/val'
test_dir = '/content/drive/MyDrive/fruit_image_dataset/dataset/test'

# 이미지 데이터 전처리 (Train, Validation, Test에 대해 각각 생성)
train_datagen = ImageDataGenerator(
    rescale=1./255,  # 이미지 정규화
    preprocessing_function=pad_to_square  # 패딩을 추가하는 함수 적용
)

val_datagen = ImageDataGenerator(
    rescale=1./255,
    preprocessing_function=pad_to_square
)

test_datagen = ImageDataGenerator(
    rescale=1./255,
    preprocessing_function=pad_to_square
)

# 이미지를 로드하고 크기 조정
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),  # EfficientNetB0의 입력 크기
    batch_size=32,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

# Input 레이어 정의
input_tensor = Input(shape=(224, 224, 3))

# EfficientNetB0 모델 가져오기 (사전 학습된 가중치 사용)
base_model = EfficientNetB0(weights='imagenet', include_top=False, input_tensor=input_tensor)

# GlobalAveragePooling2D, Dropout 및 Dense 레이어 추가
x = GlobalAveragePooling2D()(base_model.output)
x = Dropout(0.5)(x)  # 드롭아웃 레이어 추가
output_tensor = Dense(4, activation='softmax', kernel_regularizer=l2(0.001))(x)  # 정규화 적용

# 모델 정의
model = Model(inputs=input_tensor, outputs=output_tensor)

# 모델 컴파일
learning_rate = 0.001
model.compile(
    optimizer=Adam(learning_rate=learning_rate),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# 모델 저장을 위한 체크포인트 설정
checkpoint = ModelCheckpoint(
    '/content/drive/MyDrive/fruit_image_dataset/dataset/efficientnet_b0_best_model_of_adjustment1.keras',  # 모델이 저장될 경로
    monitor='val_loss',  # Validation loss를 모니터링
    save_best_only=True,  # 가장 좋은 성능을 보인 모델만 저장
    mode='min',  # Validation loss가 최소일 때 저장
    verbose=1
)

# 조기 종료 설정
early_stopping = EarlyStopping(
    monitor='val_loss',  # Validation loss를 모니터링
    patience=5,  # 성능 개선이 없을 때의 에포크 수
    restore_best_weights=True  # 성능이 가장 좋았던 가중치로 복원
)

# 모델 학습
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=val_generator,
    callbacks=[early_stopping, checkpoint],  # 조기 종료 및 체크포인트 콜백 추가
    batch_size=32
)

# %% [markdown]
# ### **3.1.1 모델 성능 평가**

# %%
from tensorflow.keras.models import load_model

# 최상의 모델 로드
best_model_path = '/content/drive/MyDrive/fruit_image_dataset/dataset/efficientnet_b0_best_model_of_adjustment1.keras'
model = load_model(best_model_path)

# 테스트 데이터셋을 사용하여 모델 성능 평가
test_loss, test_accuracy = model.evaluate(test_generator)
print(f'Test Accuracy: {test_accuracy:.4f}')
print(f'Test Loss: {test_loss:.4f}')
